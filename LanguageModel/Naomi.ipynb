# %%
import nltk
from nltk.corpus.reader import CHILDESCorpusReader
import numpy as np
import pandas as pd
from nltk.probability import FreqDist
corpus = nltk.data.find('/Users/Ershui13/nltk_data/corpora/childescorpus/')
Naomi = CHILDESCorpusReader(corpus, 'Sachs/.*.xml')

# %%
import re
from nltk.util import ngrams
import itertools

# %%
pronounlist=['i', 'me', 'you', 'he' ,'him', 'she', 'her', 'we', 'us', 'they', 'them', 'it']
Nom = ['i', 'he', 'she', 'we', 'they']
Acc = ['me', 'him', 'her', 'us', 'them']
mot_sent = Naomi.sents(speaker = ['MOT'])
Naomi_sent = Naomi.sents(speaker = ['CHI'])

# %%
def pgram (ngram):
    p_gram = []
    for gr in ngram:
        for p in pronounlist:
            if p in gr:
                p_gram.append(gr)
    return p_gram
def save(t,l):
    df = pd.DataFrame(t)
    df.to_csv(l,sep=',',index=False)

def ngram (n,sents):
    tempgram = []
    for s in sents:
        ss = ' '.join(s) 
        ss = ss.lower()
        ss = '<s> ' + ss + ' <\s>'
        tokens = [token for token in ss.split(' ') if token != '']
        output = list(ngrams(tokens, n))
        tempgram.append(output)
        gram = list(itertools.chain(*tempgram))
    return gram

# %%
Naomi_3gram = ngram(3,Naomi_sent)

# %%
save(Naomi_3gram, 'Naomi_3gram.csv')

# %%
Naomi_mot_3gram = ngram(3, mot_sent)

# %%
save(Naomi_mot_3gram, 'Naomi_mot_3gram.csv')

# %%
Naomi_p_3gram = pgram(Naomi_3gram)
Naomi_mot_p_3gram = pgram(Naomi_mot_3gram)

# %%
save(Naomi_p_3gram, 'Naomi_p_3gram.csv')
save(Naomi_mot_p_3gram, 'Naomi_mot_p_3gram.csv')
save(Naomi_2gram, 'Naomi_2gram.csv')
save(Naomi_mot_2gram,'Naomi_mot_2gram.csv')
save(Naomi_p_2gram,'Naomi_p_2gram.csv')
save(Naomi_mot_p_2gram,'Naomi_mot_p_2gram.csv')

# %%
Naomi_2gram = ngram(2,Naomi_sent )
Naomi_mot_2gram = ngram(2, mot_sent)
Naomi_p_2gram = pgram(Naomi_2gram)
Naomi_mot_p_2gram = pgram(Naomi_mot_2gram)

# %%
len(Naomi_mot_2gram)
# Out:
# 44071

# %%
Naomi_mot_p_3gram
# Out:
# [('kitty', 'say', 'it'),
#  ('say', 'it', 'again'),
#  ('it', 'again', 'love'),
#  ('yyy', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'more'),
#  ('<s>', 'you', "don't"),
#  ('you', "don't", 'like'),
#  ('<s>', 'you', "don't"),
#  ('you', "don't", 'like'),
#  ('<s>', 'you', 'want'),
#  ('you', 'want', 'to'),
#  ('one', 'to', 'me'),
#  ('to', 'me', '<\\s>'),
#  ("i'll", 'take', 'him'),
#  ('take', 'him', '<\\s>'),
#  ('<s>', 'take', 'him'),
#  ('take', 'him', '<\\s>'),
#  ('okay', 'are', 'you'),
#  ('are', 'you', 'done'),
#  ('you', 'done', 'with'),
#  ('<s>', 'are', 'you'),
#  ('are', 'you', 'going'),
#  ('you', 'going', 'to'),
#  ('to', 'give', 'them'),
#  ('give', 'them', 'to'),
#  ('them', 'to', 'me'),
#  ('them', 'to', 'me'),
#  ('to', 'me', '<\\s>'),
#  ('<s>', 'okay', 'you'),
#  ('okay', 'you', 'can'),
#  ('you', 'can', 'give'),
#  ('can', 'give', 'them'),
#  ('give', 'them', 'to'),
#  ('them', 'to', 'me'),
#  ('them', 'to', 'me'),
#  ('to', 'me', '<\\s>'),
#  ("i'll", 'show', 'them'),
#  ('show', 'them', 'to'),
#  ('them', 'to', 'you'),
#  ('them', 'to', 'you'),
#  ('to', 'you', 'another'),
#  ('you', 'another', 'time'),
#  ("she's", 'got', 'her'),
#  ('got', 'her', 'feet'),
#  ('her', 'feet', 'on'),
#  ("she's", 'got', 'her'),
#  ('got', 'her', 'feet'),
#  ('her', 'feet', '<\\s>'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'to'),
#  ('<s>', 'are', 'you'),
#  ('are', 'you', 'finished'),
#  ('you', 'finished', 'with'),
#  ('finished', 'with', 'it'),
#  ('with', 'it', '<\\s>'),
#  ('<s>', 'no', 'i'),
#  ('no', 'i', "don't"),
#  ('i', "don't", 'think'),
#  ("don't", 'think', 'you'),
#  ('think', 'you', 'want'),
#  ('you', 'want', 'any'),
#  ('<s>', 'i', "don't"),
#  ('i', "don't", 'think'),
#  ('<s>', 'i', 'think'),
#  ('i', 'think', 'you'),
#  ('i', 'think', 'you'),
#  ('think', 'you', 'had'),
#  ('you', 'had', 'better'),
#  ('dripping', "isn't", 'it'),
#  ("isn't", 'it', '<\\s>'),
#  ('<s>', 'it', 'fell'),
#  ('it', 'fell', 'right'),
#  ('off', "didn't", 'it'),
#  ("didn't", 'it', '<\\s>'),
#  ('<s>', 'it', 'fell'),
#  ('it', 'fell', 'right'),
#  ('<s>', "don't", 'you'),
#  ("don't", 'you', 'put'),
#  ('you', 'put', 'that'),
#  ('my', 'hair', 'you'),
#  ('hair', 'you', '<\\s>'),
#  ('no', "don't", 'you'),
#  ("don't", 'you', 'put'),
#  ('you', 'put', 'that'),
#  ('<s>', 'you', 'finish'),
#  ('you', 'finish', 'it'),
#  ('you', 'finish', 'it'),
#  ('finish', 'it', 'up'),
#  ('it', 'up', '<\\s>'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'remember'),
#  ('you', 'remember', 'what'),
#  ('<s>', 'try', 'it'),
#  ('try', 'it', 'honey'),
#  ('it', 'honey', 'heeheeheeheeheehee'),
#  ('oh', 'do', 'they'),
#  ('do', 'they', 'smell'),
#  ('they', 'smell', 'nice'),
#  ('<s>', 'do', 'they'),
#  ('do', 'they', 'smell'),
#  ('they', 'smell', 'pretty'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'to'),
#  ('what', 'is', 'it'),
#  ('is', 'it', '<\\s>'),
#  ('<s>', 'are', 'you'),
#  ('are', 'you', 'dancing'),
#  ('you', 'dancing', 'nomi'),
#  ('<s>', 'give', 'me'),
#  ('give', 'me', 'a'),
#  ('me', 'a', 'kiss'),
#  ('xxx', 'for', 'you'),
#  ('for', 'you', '<\\s>'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'a'),
#  ('<s>', 'we', 'saw'),
#  ('we', 'saw', 'snow'),
#  ('see', 'want', 'me'),
#  ('want', 'me', 'to'),
#  ('me', 'to', 'wash'),
#  ('on', 'let', 'me'),
#  ('let', 'me', 'get'),
#  ('me', 'get', 'you'),
#  ('me', 'get', 'you'),
#  ('get', 'you', 'xxx'),
#  ('you', 'xxx', 'here'),
#  ('<s>', 'show', 'me'),
#  ('show', 'me', 'a'),
#  ('me', 'a', 'tower'),
#  ('tower', 'show', 'me'),
#  ('show', 'me', 'a'),
#  ('me', 'a', 'tower'),
#  ('<s>', 'what', 'me'),
#  ('what', 'me', 'to'),
#  ('me', 'to', 'help'),
#  ('<s>', 'i', 'put'),
#  ('i', 'put', 'that'),
#  ('to', 'build', 'it'),
#  ('build', 'it', 'on'),
#  ('it', 'on', 'here'),
#  ('not', 'do', 'it'),
#  ('do', 'it', 'on'),
#  ('it', 'on', 'the'),
#  ('what', 'are', 'they'),
#  ('are', 'they', 'eating'),
#  ('they', 'eating', '<\\s>'),
#  ('<s>', 'you', 'can'),
#  ('you', 'can', 'see'),
#  ('<s>', 'look', 'he'),
#  ('look', 'he', 'is'),
#  ('he', 'is', 'going'),
#  ('<s>', 'he', 'is'),
#  ('he', 'is', 'going'),
#  ("that's", 'good', 'i'),
#  ('good', 'i', 'can'),
#  ('i', 'can', 'plug'),
#  ('can', 'plug', 'it'),
#  ('plug', 'it', 'right'),
#  ('it', 'right', 'in'),
#  ('<s>', 'i', 'can'),
#  ('i', 'can', 'put'),
#  ('too', 'now', 'i'),
#  ('now', 'i', 'think'),
#  ('i', 'think', '<\\s>'),
#  ('was', 'good', 'she'),
#  ('good', 'she', 'got'),
#  ('she', 'got', 'all'),
#  ('what', 'are', 'you'),
#  ('are', 'you', 'doing'),
#  ('you', 'doing', 'nomi'),
#  ('what', 'are', 'you'),
#  ('are', 'you', 'doing'),
#  ('you', 'doing', '<\\s>'),
#  ('yeah', 'but', 'i'),
#  ('but', 'i', 'decided'),
#  ('i', 'decided', 'maybe'),
#  ('decided', 'maybe', 'she'),
#  ('maybe', 'she', 'would'),
#  ('she', 'would', 'be'),
#  ('to', 'use', 'them'),
#  ('use', 'them', 'very'),
#  ('them', 'very', 'soon'),
#  ('<s>', 'did', 'you'),
#  ('did', 'you', 'leave'),
#  ('you', 'leave', 'the'),
#  ('<s>', 'if', 'you'),
#  ('if', 'you', 'want'),
#  ('you', 'want', 'to'),
#  ('to', 'call', 'it'),
#  ('call', 'it', 'that'),
#  ('it', 'that', "it's"),
#  ('fine', 'with', 'me'),
#  ('with', 'me', '<\\s>'),
#  ('<s>', 'will', 'you'),
#  ('will', 'you', 'come'),
#  ('you', 'come', 'in'),
#  ('here', 'and', 'we'),
#  ('and', 'we', 'will'),
#  ('we', 'will', 'play'),
#  ('<s>', 'is', 'it'),
#  ('is', 'it', 'goldie'),
#  ('it', 'goldie', '<\\s>'),
#  ('<s>', 'can', 'you'),
#  ('can', 'you', 'say'),
#  ('you', 'say', 'that'),
#  ("let's", 'call', 'it'),
#  ('call', 'it', 'xxx'),
#  ('it', 'xxx', 'say'),
#  ('what', 'is', 'it'),
#  ('is', 'it', '<\\s>'),
#  ('what', 'are', 'they'),
#  ('are', 'they', '<\\s>'),
#  ('<s>', 'they', 'are'),
#  ('they', 'are', 'called'),
#  ('uhhuh', 'say', 'it'),
#  ('say', 'it', 'again'),
#  ('it', 'again', '<\\s>'),
#  ('what', 'is', 'it'),
#  ('is', 'it', '<\\s>'),
#  ('how', 'do', 'you'),
#  ('do', 'you', 'say'),
#  ('you', 'say', '<\\s>'),
#  ('okay', 'say', 'it'),
#  ('say', 'it', 'again'),
#  ('it', 'again', '<\\s>'),
#  ('wheels', 'on', 'it'),
#  ('on', 'it', '<\\s>'),
#  ('<s>', 'say', 'it'),
#  ('say', 'it', 'again'),
#  ('it', 'again', 'sweetie'),
#  ('<s>', 'tell', 'me'),
#  ('tell', 'me', 'again'),
#  ('me', 'again', 'what'),
#  ('<s>', "don't", 'you'),
#  ("don't", 'you', 'draw'),
#  ('you', 'draw', 'on'),
#  ('minute', 'with', 'me'),
#  ('with', 'me', '<\\s>'),
#  ('<s>', 'i', 'want'),
#  ('i', 'want', 'to'),
#  ('to', 'hold', 'you'),
#  ('hold', 'you', 'for'),
#  ('you', 'for', 'a'),
#  ('okay', 'now', 'i'),
#  ('now', 'i', 'want'),
#  ('i', 'want', 'you'),
#  ('i', 'want', 'you'),
#  ('want', 'you', 'to'),
#  ('you', 'to', 'say'),
#  ('<s>', 'did', 'you'),
#  ('did', 'you', 'lose'),
#  ('you', 'lose', 'a'),
#  ('<s>', 'let', 'me'),
#  ('let', 'me', 'see'),
#  ('me', 'see', '<\\s>'),
#  ('<s>', 'you', 'have'),
#  ('you', 'have', 'one'),
#  ('<s>', 'are', 'you'),
#  ('are', 'you', 'riding'),
#  ('you', 'riding', 'your'),
#  ('alright', 'nomi', 'i'),
#  ('nomi', 'i', 'want'),
#  ('i', 'want', 'you'),
#  ('i', 'want', 'you'),
#  ('want', 'you', 'to'),
#  ('you', 'to', 'nap'),
#  ('<s>', 'i', 'want'),
#  ('i', 'want', 'you'),
#  ('i', 'want', 'you'),
#  ('want', 'you', 'to'),
#  ('you', 'to', 'be'),
#  ('<s>', 'no', 'you'),
#  ('no', 'you', 'lie'),
#  ('you', 'lie', 'down'),
#  ('<s>', 'you', 'lie'),
#  ('you', 'lie', 'down'),
#  ('down', 'too', 'you'),
#  ('too', 'you', 'lie'),
#  ('you', 'lie', 'down'),
#  ('<s>', 'i', 'think'),
#  ('i', 'think', 'nomi'),
#  ('<s>', 'you', 'lie'),
#  ('you', 'lie', 'down'),
#  ("let's", 'put', 'it'),
#  ('put', 'it', 'like'),
#  ('it', 'like', 'this'),
#  ('this', 'so', 'she'),
#  ('so', 'she', "won't"),
#  ('she', "won't", 'fall'),
#  ('<s>', 'there', 'she'),
#  ('there', 'she', 'goes'),
#  ('she', 'goes', '<\\s>'),
#  ('there', 'does', 'she'),
#  ('does', 'she', '<\\s>'),
#  ('<s>', 'leave', 'it'),
#  ('leave', 'it', 'over'),
#  ('it', 'over', 'here'),
#  ('not', 'using', 'it'),
#  ('using', 'it', '<\\s>'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'have'),
#  ('you', 'have', 'the'),
#  ('<s>', 'it', 'is'),
#  ('it', 'is', 'empty'),
#  ('xxx', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'to'),
#  ('neat', 'that', 'you'),
#  ('that', 'you', 'turn'),
#  ('you', 'turn', 'it'),
#  ('you', 'turn', 'it'),
#  ('turn', 'it', 'and'),
#  ('it', 'and', 'it'),
#  ('and', 'it', 'lets'),
#  ('it', 'lets', 'it'),
#  ('lets', 'it', 'go'),
#  ('it', 'go', '<\\s>'),
#  ('look', 'at', 'it'),
#  ('at', 'it', 'spin'),
#  ('it', 'spin', '<\\s>'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'to'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'to'),
#  ('oh', 'tissue', 'you'),
#  ('tissue', 'you', 'want'),
#  ('you', 'want', '<\\s>'),
#  ('<s>', 'am', 'i'),
#  ('am', 'i', 'right'),
#  ('i', 'right', '<\\s>'),
#  ('tissue', 'for', 'you'),
#  ('for', 'you', '<\\s>'),
#  ('<s>', 'here', 'you'),
#  ('here', 'you', 'go'),
#  ('you', 'go', '<\\s>'),
#  ('tissue', 'for', 'you'),
#  ('for', 'you', '<\\s>'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'to'),
#  ('<s>', 'would', 'you'),
#  ('would', 'you', 'like'),
#  ('you', 'like', 'to'),
#  ('<s>', 'would', 'you'),
#  ('would', 'you', 'like'),
#  ('you', 'like', 'to'),
#  ('<s>', 'oh', 'you'),
#  ('oh', 'you', 'want'),
#  ('you', 'want', 'to'),
#  ('<s>', 'would', 'you'),
#  ('would', 'you', 'like'),
#  ('you', 'like', 'to'),
#  ('why', "don't", 'you'),
#  ("don't", 'you', 'read'),
#  ('you', 'read', '<\\s>'),
#  ('<s>', "what's", 'she'),
#  ("what's", 'she', 'doing'),
#  ('she', 'doing', '<\\s>'),
#  ('<s>', 'i', 'just'),
#  ('i', 'just', "don't"),
#  ("don't", 'want', 'you'),
#  ('want', 'you', 'to'),
#  ('you', 'to', 'get'),
#  ('why', "don't", 'we'),
#  ("don't", 'we', 'play'),
#  ('we', 'play', 'with'),
#  ('and', 'give', 'it'),
#  ('give', 'it', 'some'),
#  ('it', 'some', 'coffee'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'see'),
#  ('you', 'see', 'a'),
#  ('<s>', 'you', 'gonna'),
#  ('you', 'gonna', 'give'),
#  ('coffee', 'coffee', 'she'),
#  ('coffee', 'she', 'says'),
#  ('she', 'says', '<\\s>'),
#  ('<s>', 'are', 'we'),
#  ('are', 'we', 'ready'),
#  ('we', 'ready', 'to'),
#  ('now', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'any'),
#  ('nomi', 'can', 'i'),
#  ('can', 'i', 'have'),
#  ('i', 'have', 'some'),
#  ('<s>', 'can', 'i'),
#  ('can', 'i', 'have'),
#  ('i', 'have', 'some'),
#  ('<s>', 'you', 'can'),
#  ('you', 'can', 'get'),
#  ('<s>', 'oh', 'you'),
#  ('oh', 'you', 'got'),
#  ('you', 'got', 'stuck'),
#  ('dolly', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', '<\\s>'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'the'),
#  ('<s>', "what's", 'he'),
#  ("what's", 'he', 'doing'),
#  ('he', 'doing', '<\\s>'),
#  ('what', 'are', 'they'),
#  ('are', 'they', 'doing'),
#  ('they', 'doing', '<\\s>'),
#  ('<s>', 'can', 'you'),
#  ('can', 'you', 'smell'),
#  ('you', 'smell', 'the'),
#  ("let's", 'put', 'it'),
#  ('put', 'it', 'over'),
#  ('it', 'over', 'here'),
#  ('and', 'let', 'it'),
#  ('let', 'it', 'rest'),
#  ('it', 'rest', '<\\s>'),
#  ('<s>', 'maybe', 'it'),
#  ('maybe', 'it', "won't"),
#  ('it', "won't", 'be'),
#  ('nomi', 'has', 'her'),
#  ('has', 'her', 'glasses'),
#  ('her', 'glasses', 'on'),
#  ('<s>', 'she', 'looks'),
#  ('she', 'looks', 'like'),
#  ('<s>', 'she', 'looks'),
#  ('she', 'looks', 'like'),
#  ('<s>', 'she', 'looks'),
#  ('she', 'looks', 'like'),
#  ('what', 'are', 'they'),
#  ('are', 'they', 'doing'),
#  ('they', 'doing', '<\\s>'),
#  ('no', 'nomi', 'you'),
#  ('nomi', 'you', "can't"),
#  ('you', "can't", 'walk'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'some'),
#  ('happen', 'when', 'you'),
#  ('when', 'you', 'put'),
#  ('you', 'put', 'your'),
#  ("you'll", 'get', 'it'),
#  ('get', 'it', 'all'),
#  ('it', 'all', 'damp'),
#  ('<s>', 'let', 'me'),
#  ('let', 'me', 'get'),
#  ('me', 'get', 'you'),
#  ('me', 'get', 'you'),
#  ('get', 'you', 'a'),
#  ('you', 'a', 'fresh'),
#  ('<s>', 'i', "don't"),
#  ('i', "don't", 'want'),
#  ("don't", 'want', 'you'),
#  ('want', 'you', 'to'),
#  ('you', 'to', 'get'),
#  ('<s>', 'i', "don't"),
#  ('i', "don't", 'want'),
#  ("don't", 'want', 'you'),
#  ('want', 'you', 'to'),
#  ('you', 'to', 'get'),
#  ('<s>', 'i', 'have_to'),
#  ('i', 'have_to', 'get'),
#  ('have_to', 'get', 'you'),
#  ('get', 'you', 'a'),
#  ('you', 'a', 'diaper'),
#  ('what', 'is', 'it'),
#  ('is', 'it', 'called'),
#  ('it', 'called', '<\\s>'),
#  ('<s>', 'nomi', 'you'),
#  ('nomi', 'you', 'say'),
#  ('you', 'say', 'nomi'),
#  ('nomi', 'when', 'i'),
#  ('when', 'i', 'say'),
#  ('i', 'say', '<\\s>'),
#  ('say', 'when', 'i'),
#  ('when', 'i', 'say'),
#  ('i', 'say', '<\\s>'),
#  ('how', 'can', 'i'),
#  ('can', 'i', 'take'),
#  ('i', 'take', 'my'),
#  ('how', 'can', 'i'),
#  ('can', 'i', 'take'),
#  ('i', 'take', 'my'),
#  ('<s>', 'say', 'it'),
#  ('say', 'it', '<\\s>'),
#  ('<s>', 'i', "can't"),
#  ('i', "can't", 'see'),
#  ("can't", 'see', 'her'),
#  ('see', 'her', '<\\s>'),
#  ('where', 'is', 'she'),
#  ('is', 'she', '<\\s>'),
#  ('where', 'is', 'she'),
#  ('is', 'she', '<\\s>'),
#  ('where', 'is', 'she'),
#  ('is', 'she', '<\\s>'),
#  ('<s>', 'is', 'she'),
#  ('is', 'she', 'a'),
#  ('she', 'a', 'creep'),
#  ('<s>', 'is', 'she'),
#  ('is', 'she', 'a'),
#  ('she', 'a', 'creep'),
#  ('wet', 'because', 'you'),
#  ('because', 'you', "don't"),
#  ('you', "don't", 'have'),
#  ('<s>', 'are', 'you'),
#  ('are', 'you', 'surprised'),
#  ('you', 'surprised', '<\\s>'),
#  ("don't", 'tear', 'it'),
#  ('tear', 'it', '<\\s>'),
#  ("you're", 'tearing', 'it'),
#  ('tearing', 'it', '<\\s>'),
#  ("don't", 'tear', 'it'),
#  ('tear', 'it', '<\\s>'),
#  ('<s>', 'let', 'me'),
#  ('let', 'me', 'attach'),
#  ('me', 'attach', 'you'),
#  ('me', 'attach', 'you'),
#  ('attach', 'you', '<\\s>'),
#  ('<s>', 'fasten', 'you'),
#  ('fasten', 'you', 'up'),
#  ('you', 'up', 'again'),
#  ('a', 'minute', 'you'),
#  ('minute', 'you', 'fall'),
#  ('you', 'fall', 'down'),
#  ('<s>', 'you', 'fall'),
#  ('you', 'fall', 'down'),
#  ('<s>', 'you', 'fall'),
#  ('you', 'fall', 'down'),
#  ('<s>', 'can', 'you'),
#  ('can', 'you', 'say'),
#  ('you', 'say', 'that'),
#  ('oh', 'is', 'it'),
#  ('is', 'it', 'cute'),
#  ('it', 'cute', '<\\s>'),
#  ('<s>', 'is', 'it'),
#  ('is', 'it', 'cute'),
#  ('it', 'cute', '<\\s>'),
#  ('<s>', 'oh', 'you'),
#  ('oh', 'you', '<\\s>'),
#  ('<s>', 'you', 'fell'),
#  ('you', 'fell', 'down'),
#  ('down', "didn't", 'you'),
#  ("didn't", 'you', '<\\s>'),
#  ('oh', 'nomi', 'you'),
#  ('nomi', 'you', 'have'),
#  ('you', 'have', 'so'),
#  ('<s>', 'you', 'keep'),
#  ('you', 'keep', 'stepping'),
#  ('toys', "don't", 'you'),
#  ("don't", 'you', '<\\s>'),
#  ('<s>', 'you', 'keep'),
#  ('you', 'keep', 'stepping'),
#  ('stepping', 'on', 'them'),
#  ('on', 'them', '<\\s>'),
#  ('nomi', 'can', 'you'),
#  ('can', 'you', 'find'),
#  ('you', 'find', 'the'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'to'),
#  ('<s>', 'you', 'lie'),
#  ('you', 'lie', 'in'),
#  ('several', 'of', 'them'),
#  ('of', 'them', 'to'),
#  ('them', 'to', 'get'),
#  ('<s>', 'here', 'i'),
#  ('here', 'i', 'come'),
#  ('i', 'come', 'with'),
#  ('yeah', 'well', 'you'),
#  ('well', 'you', 'lie'),
#  ('you', 'lie', 'down'),
#  ('<s>', 'you', 'want'),
#  ('you', 'want', 'a'),
#  ('tissue', "don't", 'you'),
#  ("don't", 'you', 'tissue'),
#  ('you', 'tissue', 'we'),
#  ('you', 'tissue', 'we'),
#  ('tissue', 'we', 'should'),
#  ('we', 'should', 'dry'),
#  ('nomi', 'would', 'you'),
#  ('would', 'you', 'say'),
#  ('you', 'say', '<\\s>'),
#  ('<s>', 'are', 'you'),
#  ('are', 'you', 'going'),
#  ('you', 'going', 'to'),
#  ('to', 'tell', 'us'),
#  ('tell', 'us', 'when'),
#  ('us', 'when', 'you'),
#  ('us', 'when', 'you'),
#  ('when', 'you', 'have_to'),
#  ('you', 'have_to', 'tinkle'),
#  ('<s>', 'you', 'can'),
#  ('you', 'can', 'put'),
#  ('<s>', 'it', 'is'),
#  ('it', 'is', 'called'),
#  ('<s>', 'and', 'it'),
#  ('and', 'it', 'is'),
#  ('it', 'is', 'called'),
#  ('<s>', 'is', 'it'),
#  ('is', 'it', 'a'),
#  ('it', 'a', 'no'),
#  ('<s>', 'is', 'it'),
#  ('is', 'it', 'a'),
#  ('it', 'a', 'no'),
#  ('color', 'is', 'it'),
#  ('is', 'it', '<\\s>'),
#  ('<s>', 'is', 'it'),
#  ('is', 'it', 'black'),
#  ('it', 'black', '<\\s>'),
#  ('<s>', 'can', 'you'),
#  ('can', 'you', 'say'),
#  ('you', 'say', '<\\s>'),
#  ('<s>', 'can', 'you'),
#  ('can', 'you', 'say'),
#  ('you', 'say', '<\\s>'),
#  ('nomi', 'can', 'you'),
#  ('can', 'you', 'say'),
#  ('you', 'say', '<\\s>'),
#  ('<s>', 'can', 'you'),
#  ('can', 'you', 'say'),
#  ('you', 'say', '<\\s>'),
#  ('nomi', 'can', 'you'),
#  ('can', 'you', 'say'),
#  ('you', 'say', '<\\s>'),
#  ('<s>', 'i', 'found'),
#  ('i', 'found', 'the'),
#  ('<s>', 'did', 'you'),
#  ('did', 'you', 'hurt'),
#  ('you', 'hurt', 'your'),
#  ('<s>', 'you', 'got'),
#  ('you', 'got', 'a'),
#  ('<s>', 'did', 'you'),
#  ('did', 'you', 'hurt'),
#  ('you', 'hurt', 'your'),
#  ('<s>', 'oh', 'you'),
#  ('oh', 'you', 'fell'),
#  ('you', 'fell', 'down'),
#  ('<s>', 'would', 'you'),
#  ('would', 'you', 'like'),
#  ('you', 'like', 'to'),
#  ("don't", 'hit', 'it'),
#  ('hit', 'it', '<\\s>'),
#  ("don't", 'push', 'it'),
#  ('push', 'it', '<\\s>'),
#  ('<s>', 'it', 'makes'),
#  ('it', 'makes', 'it'),
#  ('makes', 'it', 'stop'),
#  ('it', 'stop', '<\\s>'),
#  ("it's", 'okay', 'it'),
#  ('okay', 'it', 'will'),
#  ('it', 'will', 'dry'),
#  ('<s>', 'tie', 'it'),
#  ('tie', 'it', '<\\s>'),
#  ('<s>', 'maybe', 'we'),
#  ('maybe', 'we', 'could'),
#  ('we', 'could', 'put'),
#  ('<s>', 'he', 'could'),
#  ('he', 'could', 'have'),
#  ('off', 'of', 'him'),
#  ('of', 'him', '<\\s>'),
#  ('<s>', 'now', 'you'),
#  ('now', 'you', 'can'),
#  ('you', 'can', 'put'),
#  ('<s>', 'now', 'you'),
#  ('now', 'you', 'can'),
#  ('you', 'can', 'get'),
#  ('<s>', 'you', 'want'),
#  ('you', 'want', 'it'),
#  ('you', 'want', 'it'),
#  ('want', 'it', 'off'),
#  ('it', 'off', '<\\s>'),
#  ('okay', 'want', 'it'),
#  ('want', 'it', 'off'),
#  ('it', 'off', '<\\s>'),
#  ('<s>', 'pull', 'them'),
#  ('pull', 'them', 'up'),
#  ('them', 'up', '<\\s>'),
#  ('<s>', 'is', 'he'),
#  ('is', 'he', 'sleeping'),
#  ('he', 'sleeping', 'do'),
#  ('sleeping', 'do', 'you'),
#  ('do', 'you', 'think'),
#  ('you', 'think', '<\\s>'),
#  ('<s>', 'okay', 'you'),
#  ('okay', 'you', 'can'),
#  ('you', 'can', 'take'),
#  ('can', 'take', 'them'),
#  ('take', 'them', 'off'),
#  ('them', 'off', '<\\s>'),
#  ('oh', 'sure', 'you'),
#  ('sure', 'you', 'can'),
#  ('you', 'can', 'honey'),
#  ('<s>', 'there', 'they'),
#  ('there', 'they', 'are'),
#  ('they', 'are', 'all'),
#  ('down', "isn't", 'he'),
#  ("isn't", 'he', '<\\s>'),
#  ('<s>', 'tell', 'him'),
#  ('tell', 'him', 'not'),
#  ('him', 'not', 'to'),
#  ('<s>', 'tell', 'him'),
#  ('tell', 'him', 'not'),
#  ('him', 'not', 'to'),
#  ('smiling', "isn't", 'he'),
#  ("isn't", 'he', '<\\s>'),
#  ('<s>', 'tell', 'him'),
#  ('tell', 'him', 'not'),
#  ('him', 'not', 'to'),
#  ('<s>', 'he', 'fell'),
#  ('he', 'fell', 'down'),
#  ('down', "didn't", 'he'),
#  ("didn't", 'he', '<\\s>'),
#  ('<s>', 'tell', 'him'),
#  ('tell', 'him', 'not'),
#  ('him', 'not', 'to'),
#  ('big', "isn't", 'it'),
#  ("isn't", 'it', '<\\s>'),
#  ('<s>', 'no', 'it'),
#  ('no', 'it', "doesn't"),
#  ('it', "doesn't", 'go'),
#  ('play', 'with', 'me'),
#  ('with', 'me', '<\\s>'),
#  ('babies', 'missed', 'you'),
#  ('missed', 'you', 'while'),
#  ('you', 'while', 'you'),
#  ('while', 'you', 'were'),
#  ('you', 'were', 'away'),
#  ('<s>', 'they', 'want'),
#  ('they', 'want', 'you'),
#  ('they', 'want', 'you'),
#  ('want', 'you', 'to'),
#  ('you', 'to', 'come'),
#  ('play', 'with', 'them'),
#  ('with', 'them', '<\\s>'),
#  ('<s>', 'see', 'you'),
#  ('see', 'you', 'later'),
#  ('you', 'later', '<\\s>'),
#  ('what', 'are', 'you'),
#  ('are', 'you', 'doing'),
#  ('you', 'doing', 'nomi'),
#  ('oh', 'would', 'you'),
#  ('would', 'you', 'like'),
#  ('you', 'like', 'to'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'to'),
#  ('<s>', 'oh', 'you'),
#  ('oh', 'you', 'found'),
#  ('you', 'found', 'the'),
#  ('why', "don't", 'we'),
#  ("don't", 'we', 'take'),
#  ('we', 'take', 'the'),
#  ('the', 'one', 'you'),
#  ('one', 'you', 'have'),
#  ('you', 'have', 'on'),
#  ('why', "don't", 'we'),
#  ("don't", 'we', 'take'),
#  ('we', 'take', 'it'),
#  ('we', 'take', 'it'),
#  ('take', 'it', 'off'),
#  ('it', 'off', '<\\s>'),
#  ('small', 'for', 'you'),
#  ('for', 'you', 'now'),
#  ('you', 'now', '<\\s>'),
#  ('<s>', 'you', 'going'),
#  ('you', 'going', 'to'),
#  ('<s>', 'would', 'you'),
#  ('would', 'you', 'let'),
#  ('you', 'let', 'mommy'),
#  ('<s>', 'see', 'you'),
#  ('see', 'you', 'later'),
#  ('you', 'later', '<\\s>'),
#  ('well', 'if', 'we'),
#  ('if', 'we', 'took'),
#  ('we', 'took', 'your'),
#  ('sleeper', 'off', 'we'),
#  ('off', 'we', 'could'),
#  ('we', 'could', 'put'),
#  ('<s>', 'we', 'could'),
#  ('we', 'could', 'put'),
#  ('<s>', 'something', 'you'),
#  ('something', 'you', 'have'),
#  ('you', 'have', 'never'),
#  ('boy', 'have', 'you'),
#  ('have', 'you', 'got'),
#  ('you', 'got', 'a'),
#  ('boy', 'have', 'you'),
#  ('have', 'you', 'got'),
#  ('you', 'got', 'a'),
#  ('will', 'help', 'you'),
#  ('help', 'you', 'honey'),
#  ('you', 'honey', 'mommy'),
#  ('will', 'help', 'you'),
#  ('help', 'you', 'honey'),
#  ('you', 'honey', '<\\s>'),
#  ('<s>', 'i', 'put'),
#  ('i', 'put', 'them'),
#  ('i', 'put', 'them'),
#  ('put', 'them', 'right'),
#  ('them', 'right', 'up'),
#  ('<s>', 'we', "don't"),
#  ('we', "don't", 'want'),
#  ('<s>', 'you', 'want'),
#  ('you', 'want', 'a'),
#  ('<s>', 'you', 'have_to'),
#  ('you', 'have_to', 'be'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'some'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'some'),
#  ("i'll", 'cut', 'it'),
#  ('cut', 'it', 'nomi'),
#  ('it', 'nomi', 'and'),
#  ('then', 'if', 'you'),
#  ('if', 'you', 'want'),
#  ('you', 'want', 'it'),
#  ('you', 'want', 'it'),
#  ('want', 'it', 'you'),
#  ('want', 'it', 'you'),
#  ('it', 'you', 'can'),
#  ('it', 'you', 'can'),
#  ('you', 'can', 'put'),
#  ('can', 'put', 'it'),
#  ('put', 'it', 'on'),
#  ('it', 'on', 'yourself'),
#  ('<s>', 'yesterday', 'you'),
#  ('yesterday', 'you', "didn't"),
#  ('you', "didn't", 'want'),
#  ("didn't", 'want', 'it'),
#  ('want', 'it', 'when'),
#  ('it', 'when', 'i'),
#  ('it', 'when', 'i'),
#  ('when', 'i', 'made'),
#  ('i', 'made', 'it'),
#  ('i', 'made', 'it'),
#  ('made', 'it', 'for'),
#  ('it', 'for', 'you'),
#  ('it', 'for', 'you'),
#  ('for', 'you', '<\\s>'),
#  ('<s>', 'you', 'have_to'),
#  ('you', 'have_to', 'just'),
#  ('<s>', 'sweetie', 'i'),
#  ('sweetie', 'i', "don't"),
#  ('i', "don't", 'want'),
#  ("don't", 'want', 'you'),
#  ('want', 'you', 'flopping'),
#  ('you', 'flopping', 'around'),
#  ('<s>', 'i', "don't"),
#  ('i', "don't", 'want'),
#  ("don't", 'want', 'you'),
#  ('want', 'you', 'flopping'),
#  ('you', 'flopping', 'around'),
#  ('<s>', 'i', "didn't"),
#  ('i', "didn't", 'put'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'know'),
#  ('you', 'know', 'what'),
#  ('know', 'what', 'you'),
#  ('what', 'you', 'would'),
#  ('you', 'would', 'like'),
#  ('yeah', 'what', 'you'),
#  ('what', 'you', 'would'),
#  ('you', 'would', 'like'),
#  ('what', 'do', 'you'),
#  ('do', 'you', 'like'),
#  ('you', 'like', 'to'),
#  ('<s>', 'is', 'it'),
#  ('is', 'it', 'good'),
#  ('it', 'good', 'honey'),
#  ('flower', 'on', 'it'),
#  ('on', 'it', '<\\s>'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'see'),
#  ('you', 'see', 'it'),
#  ('you', 'see', 'it'),
#  ('see', 'it', 'has'),
#  ('it', 'has', 'a'),
#  ('what', 'do', 'you'),
#  ('do', 'you', 'think'),
#  ('you', 'think', 'it'),
#  ('you', 'think', 'it'),
#  ('think', 'it', 'is'),
#  ('it', 'is', '<\\s>'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'more'),
#  ('have_to', 'get', 'it'),
#  ('get', 'it', '<\\s>'),
#  ('<s>', 'you', "don't"),
#  ('you', "don't", 'eat'),
#  ("don't", 'eat', 'it'),
#  ('eat', 'it', 'with'),
#  ('it', 'with', 'your'),
#  ('<s>', 'here', 'it'),
#  ('here', 'it', 'is'),
#  ('it', 'is', '<\\s>'),
#  ("that's", 'what', 'i'),
#  ('what', 'i', 'mean'),
#  ('i', 'mean', 'by'),
#  ('<s>', 'i', "don't"),
#  ('i', "don't", 'want'),
#  ("don't", 'want', 'you'),
#  ('want', 'you', 'flopping'),
#  ('you', 'flopping', 'around'),
#  ('<s>', 'i', "don't"),
#  ('i', "don't", 'want'),
#  ("don't", 'want', 'you'),
#  ('want', 'you', 'flopping'),
#  ('you', 'flopping', 'around'),
#  ('<s>', 'i', 'want'),
#  ('i', 'want', 'you'),
#  ('i', 'want', 'you'),
#  ('want', 'you', 'to'),
#  ('you', 'to', 'sit'),
#  ('<s>', 'i', "don't"),
#  ('i', "don't", 'want'),
#  ("don't", 'want', 'you'),
#  ('want', 'you', 'to'),
#  ('you', 'to', 'get'),
#  ('<s>', 'i', 'want'),
#  ('i', 'want', 'you'),
#  ('i', 'want', 'you'),
#  ('want', 'you', 'to'),
#  ('you', 'to', 'you'),
#  ('to', 'you', 'said'),
#  ('you', 'said', 'you'),
#  ('said', 'you', 'wanted'),
#  ('you', 'wanted', 'more'),
#  ('<s>', 'are', 'you'),
#  ('are', 'you', 'going'),
#  ('you', 'going', 'to'),
#  ('hang', 'onto', 'it'),
#  ('onto', 'it', 'this'),
#  ('it', 'this', 'time'),
#  ('<s>', 'would', 'you'),
#  ('would', 'you', 'like'),
#  ('you', 'like', 'some'),
#  ('flowers', 'on', 'it'),
#  ('on', 'it', '<\\s>'),
#  ('<s>', 'you', 'sleep'),
#  ('you', 'sleep', 'in'),
#  ('<s>', 'can', 'you'),
#  ('can', 'you', 'say'),
#  ('you', 'say', '<\\s>'),
#  ('<s>', 'you', 'banged'),
#  ('you', 'banged', 'your'),
#  ("you're", 'banging', 'it'),
#  ('banging', 'it', 'into'),
#  ('it', 'into', 'the'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'want'),
#  ('you', 'want', 'me'),
#  ('you', 'want', 'me'),
#  ('want', 'me', 'to'),
#  ('me', 'to', 'put'),
#  ('<s>', 'you', 'want'),
#  ('you', 'want', 'that'),
#  ('<s>', 'her', 'eyes'),
#  ('her', 'eyes', 'are'),
#  ('look', 'at', 'her'),
#  ('at', 'her', 'eyes'),
#  ('her', 'eyes', '<\\s>'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'know'),
#  ('you', 'know', 'what'),
#  ('<s>', "where's", 'her'),
#  ("where's", 'her', 'smile'),
#  ('her', 'smile', '<\\s>'),
#  ('<s>', "where's", 'her'),
#  ("where's", 'her', 'smile'),
#  ('her', 'smile', '<\\s>'),
#  ('<s>', 'do', 'you'),
#  ('do', 'you', 'know'),
#  ('you', 'know', 'what'),
#  ('nomi', 'can', 'you'),
#  ('can', 'you', 'say'),
#  ('you', 'say', '<\\s>'),
#  ('<s>', 'i', 'think'),
#  ('i', 'think', 'maybe'),
#  ('think', 'maybe', 'we'),
#  ('maybe', 'we', 'call'),
#  ('we', 'call', 'that'),
#  ('nomi', 'did', 'you'),
#  ('did', 'you', 'have'),
#  ('you', 'have', 'enough'),
#  ('<s>', 'you', 'were'),
#  ('you', 'were', 'all'),
#  ('good', 'that', 'you'),
#  ('that', 'you', "can't"),
#  ('you', "can't", "you're"),
#  ("don't", 'open', 'it'),
#  ('open', 'it', '<\\s>'),
#  ('<s>', 'oh', 'you'),
#  ('oh', 'you', 'dropped'),
#  ...]

# %%
Naomi_mot_aX_Nom = [pair for pair in Naomi_mot_p_2gram if pair[1] in Nom]
Naomi_mot_aX_Acc = [pair for pair in Naomi_mot_p_2gram if pair[1] in Acc]
Naomi_mot_Xb_Nom = [pair for pair in Naomi_mot_p_2gram if pair[0] in Nom]
Naomi_mot_Xb_Acc = [pair for pair in Naomi_mot_p_2gram if pair[0] in Acc]

# %%
Naomi_mot_aXb_Nom = [p for p in Naomi_mot_p_3gram if p[1] in Nom]
Naomi_mot_aXb_Acc = [p for p in Naomi_mot_p_3gram if p[1] in Acc]
Naomi_mot_aNXb = [(pair[0],'X',pair[2]) for pair in Naomi_mot_aXb_Nom]
Naomi_mot_aAXb = [(pair[0],'X',pair[2]) for pair in Naomi_mot_aXb_Acc]

# %%
Naomi_aXb_Nom = [p for p in Naomi_p_3gram if p[1] in Nom]
Naomi_aXb_Acc = [p for p in Naomi_p_3gram if p[1] in Acc]

# %%
len(Naomi_mot_aXb_Nom)
# Out:
# 926

# %%
Naomi_mot_Xb_Nom
# Out:
# [('i', "don't"),
#  ('i', "don't"),
#  ('i', 'think'),
#  ('they', 'smell'),
#  ('they', 'smell'),
#  ('we', 'saw'),
#  ('i', 'put'),
#  ('they', 'eating'),
#  ('he', 'is'),
#  ('he', 'is'),
#  ('i', 'can'),
#  ('i', 'can'),
#  ('i', 'think'),
#  ('she', 'got'),
#  ('i', 'decided'),
#  ('she', 'would'),
#  ('we', 'will'),
#  ('they', '<\\s>'),
#  ('they', 'are'),
#  ('i', 'want'),
#  ('i', 'want'),
#  ('i', 'want'),
#  ('i', 'want'),
#  ('i', 'think'),
#  ('she', "won't"),
#  ('she', 'goes'),
#  ('she', '<\\s>'),
#  ('i', 'right'),
#  ('she', 'doing'),
#  ('i', 'just'),
#  ('we', 'play'),
#  ('she', 'says'),
#  ('we', 'ready'),
#  ('i', 'have'),
#  ('i', 'have'),
#  ('he', 'doing'),
#  ('they', 'doing'),
#  ('she', 'looks'),
#  ('she', 'looks'),
#  ('she', 'looks'),
#  ('they', 'doing'),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', 'have_to'),
#  ('i', 'say'),
#  ('i', 'say'),
#  ('i', 'take'),
#  ('i', 'take'),
#  ('i', "can't"),
#  ('she', '<\\s>'),
#  ('she', '<\\s>'),
#  ('she', '<\\s>'),
#  ('she', 'a'),
#  ('she', 'a'),
#  ('i', 'come'),
#  ('we', 'should'),
#  ('i', 'found'),
#  ('we', 'could'),
#  ('he', 'could'),
#  ('he', 'sleeping'),
#  ('they', 'are'),
#  ('he', '<\\s>'),
#  ('he', '<\\s>'),
#  ('he', 'fell'),
#  ('he', '<\\s>'),
#  ('they', 'want'),
#  ('we', 'take'),
#  ('we', 'take'),
#  ('we', 'took'),
#  ('we', 'could'),
#  ('we', 'could'),
#  ('i', 'put'),
#  ('we', "don't"),
#  ('i', 'made'),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', "didn't"),
#  ('i', 'mean'),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', 'want'),
#  ('i', "don't"),
#  ('i', 'want'),
#  ('i', 'think'),
#  ('we', 'call'),
#  ('they', "won't"),
#  ('she', '<\\s>'),
#  ('i', 'think'),
#  ('i', "don't"),
#  ('he', 'wanted'),
#  ('they', 'have_to'),
#  ('she', "can't"),
#  ('she', 'cries'),
#  ('we', 'could'),
#  ('he', 'makes'),
#  ('he', '<\\s>'),
#  ('we', 'make'),
#  ('we', "don't"),
#  ('we', 'plan'),
#  ('we', 'get'),
#  ('we', 'could'),
#  ('we', 'will'),
#  ('we', 'will'),
#  ('i', "don't"),
#  ('we', "don't"),
#  ('he', 'has'),
#  ('i', "don't"),
#  ('we', "don't"),
#  ('she', 'has'),
#  ('we', 'could'),
#  ('we', 'have'),
#  ('we', 'have'),
#  ('we', 'have'),
#  ('he', 'must'),
#  ('i', 'think'),
#  ('we', 'just'),
#  ('i', "don't"),
#  ('we', 'have'),
#  ('we', 'have'),
#  ('i', "don't"),
#  ('i', 'drop'),
#  ('we', 'have_to'),
#  ('he', "didn't"),
#  ('i', 'wan'),
#  ('he', 'went'),
#  ('she', 'has'),
#  ('we', 'do'),
#  ('we', 'do'),
#  ('we', 'ride'),
#  ('we', 'rode'),
#  ('i', 'better'),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', 'believe'),
#  ('she', 'has'),
#  ('she', 'has'),
#  ('i', 'had'),
#  ('they', '<\\s>'),
#  ('i', 'find'),
#  ('they', 'eating'),
#  ('they', 'eating'),
#  ('i', "don't"),
#  ('she', '<\\s>'),
#  ('she', '<\\s>'),
#  ('i', "can't"),
#  ('we', 'have_to'),
#  ('she', 'wants'),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('we', "don't"),
#  ('she', 'want'),
#  ('she', 'wants'),
#  ('they', 'doing'),
#  ('they', 'doing'),
#  ('they', 'doing'),
#  ('they', 'doing'),
#  ('they', 'doing'),
#  ('she', 'wants'),
#  ('we', 'asked'),
#  ('we', 'know'),
#  ('she', 'always'),
#  ('i', 'want'),
#  ('we', 'put'),
#  ('i', 'got'),
#  ('he', 'woke'),
#  ('he', '<\\s>'),
#  ('he', 'want'),
#  ('i', 'want'),
#  ('i', 'want'),
#  ('he', 'like'),
#  ('he', 'like'),
#  ('he', 'like'),
#  ('he', 'like'),
#  ('i', 'like'),
#  ('he', 'likes'),
#  ('he', 'likes'),
#  ('he', '<\\s>'),
#  ('he', 'doing'),
#  ('i', 'am'),
#  ('we', 'go'),
#  ('we', 'get'),
#  ('she', 'says'),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', 'tried'),
#  ('i', 'hope'),
#  ('i', 'hope'),
#  ('we', 'want'),
#  ('i', "don't"),
#  ('i', 'was'),
#  ('i', 'was'),
#  ('he', '<\\s>'),
#  ('i', 'have_to'),
#  ('we', 'said'),
#  ('we', 'talked'),
#  ('we', 'did'),
#  ('we', "didn't"),
#  ('he', 'had'),
#  ('i', 'put'),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', 'heard'),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', 'see'),
#  ('i', 'see'),
#  ('she', 'made'),
#  ('i', "don't"),
#  ('we', 'told'),
#  ('i', 'thought'),
#  ('we', 'were'),
#  ('she', 'really'),
#  ('i', 'see'),
#  ('i', "don't"),
#  ('i', 'see'),
#  ('i', "don't"),
#  ('i', 'guess'),
#  ('i', 'think'),
#  ('i', 'think'),
#  ('i', "don't"),
#  ('he', 'swishes'),
#  ('she', 'did'),
#  ('she', 'did'),
#  ('i', 'know'),
#  ('i', 'know'),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', 'doing'),
#  ('i', 'see'),
#  ('i', "don't"),
#  ('he', 'has'),
#  ('we', 'have'),
#  ('she', '<\\s>'),
#  ('i', "don't"),
#  ('i', 'i'),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', 'guess'),
#  ('she', 'looks'),
#  ('she', 'did'),
#  ('she', 'doing'),
#  ('she', 'talking'),
#  ('i', "won't"),
#  ('i', 'can'),
#  ('i', 'loving'),
#  ('they', 'want'),
#  ('they', 'want'),
#  ('they', 'want'),
#  ('they', 'want'),
#  ('they', 'want'),
#  ('he', 'was'),
#  ('they', 'want'),
#  ('she', 'want'),
#  ('i', 'want'),
#  ('she', '<\\s>'),
#  ('she', 'is'),
#  ('she', 'have'),
#  ('he', 'have'),
#  ('he', 'have'),
#  ('he', 'has'),
#  ('i', 'think'),
#  ('we', 'do'),
#  ('i', "don't"),
#  ('he', 'got'),
#  ('he', 'had'),
#  ('he', 'had'),
#  ('he', 'had'),
#  ('he', 'had'),
#  ('i', 'see'),
#  ('i', 'see'),
#  ('i', 'can'),
#  ('i', 'took'),
#  ('we', 'eat'),
#  ('we', "don't"),
#  ('i', 'ate'),
#  ('i', 'eat'),
#  ('she', "doesn't"),
#  ('she', "wasn't"),
#  ('i', 'think'),
#  ('we', "don't"),
#  ('we', 'can'),
#  ('we', 'have_to'),
#  ('we', 'in'),
#  ('he', 'lying'),
#  ('he', 'sleep'),
#  ('he', 'like'),
#  ('he', 'like'),
#  ('he', 'likes'),
#  ('he', 'like'),
#  ('they', 'like'),
#  ('he', 'likes'),
#  ('he', 'eating'),
#  ('he', 'eating'),
#  ('i', "don't"),
#  ('i', 'wondered'),
#  ('i', 'was'),
#  ('i', 'was'),
#  ('he', 'broke'),
#  ('he', 'fixed'),
#  ('i', 'want'),
#  ('he', 'fixed'),
#  ('he', '<\\s>'),
#  ('i', 'see'),
#  ('i', 'see'),
#  ('i', "don't"),
#  ('i', "didn't"),
#  ('i', 'said'),
#  ('i', "don't"),
#  ('i', 'have_to'),
#  ('they', 'would'),
#  ('he', 'eat'),
#  ('he', 'have'),
#  ('they', '<\\s>'),
#  ('they', 'make'),
#  ('we', "don't"),
#  ('we', "don't"),
#  ('we', "don't"),
#  ('i', 'want'),
#  ('i', 'never'),
#  ('i', 'think'),
#  ('i', 'think'),
#  ('i', 'have'),
#  ('i', 'let'),
#  ('i', 'have'),
#  ('he', 'gets'),
#  ('he', 'gonna'),
#  ('he', 'gets'),
#  ('he', 'gonna'),
#  ('he', 'gonna'),
#  ('he', 'going'),
#  ('he', 'going'),
#  ('he', 'going'),
#  ('he', 'going'),
#  ('he', 'going'),
#  ('we', 'going'),
#  ('they', 'would'),
#  ('she', 'sad'),
#  ('i', "didn't"),
#  ('i', "didn't"),
#  ('i', 'was'),
#  ('i', '<\\s>'),
#  ('i', 'get'),
#  ('i', "didn't"),
#  ('i', 'got'),
#  ('i', 'called'),
#  ('i', 'got'),
#  ('i', 'want'),
#  ('i', 'call'),
#  ('i', "don't"),
#  ('i', 'just'),
#  ('i', 'was'),
#  ('i', "don't"),
#  ('i', 'wish'),
#  ('i', "don't"),
#  ('we', 'do'),
#  ('he', 'call'),
#  ('i', 'just'),
#  ('i', 'think'),
#  ('they', 'doing'),
#  ('they', 'doing'),
#  ('they', 'hugging'),
#  ('i', "don't"),
#  ('we', 'finish'),
#  ('we', "don't"),
#  ('she', 'going'),
#  ('he', 'likes'),
#  ('i', 'could'),
#  ('he', 'hit'),
#  ('i', 'have_to'),
#  ('i', 'have'),
#  ('i', 'have'),
#  ('i', 'have'),
#  ('we', 'know'),
#  ('she', 'said'),
#  ('i', "don't"),
#  ('she', '<\\s>'),
#  ('she', 'cries'),
#  ('he', 'does'),
#  ('i', "don't"),
#  ('we', 'read'),
#  ('they', 'have'),
#  ('we', 'read'),
#  ('she', 'talk'),
#  ('she', 'tell'),
#  ('they', 'go'),
#  ('we', 'have'),
#  ('i', 'wonder'),
#  ('i', 'make'),
#  ('i', 'wanted'),
#  ('i', 'wanted'),
#  ('they', 'cooking'),
#  ('they', 'cooking'),
#  ('they', 'cooking'),
#  ('i', 'left'),
#  ('i', 'think'),
#  ('we', "can't"),
#  ('i', 'stepped'),
#  ('i', 'did'),
#  ('she', 'tell'),
#  ('she', "wasn't"),
#  ('i', "don't"),
#  ('i', 'suspect'),
#  ('i', 'have'),
#  ('i', "don't"),
#  ('i', 'put'),
#  ('we', 'get'),
#  ('he', 'scares'),
#  ('i', "don't"),
#  ('i', 'got'),
#  ('we', 'like'),
#  ('she', 'doing'),
#  ('she', 'was'),
#  ('they', 'doing'),
#  ('i', "don't"),
#  ('she', 'fixes'),
#  ('she', 'fixed'),
#  ('i', 'was'),
#  ('i', 'want'),
#  ('i', 'thought'),
#  ('i', 'pick'),
#  ('i', 'have_to'),
#  ('we', 'like'),
#  ('he', 'is'),
#  ('she', 'says'),
#  ('i', 'know'),
#  ('i', 'want'),
#  ('she', 'has'),
#  ('she', 'said'),
#  ('we', "don't"),
#  ('we', 'can'),
#  ('they', "didn't"),
#  ('they', 'put'),
#  ('he', 'has'),
#  ('he', 'has'),
#  ('he', 'looks'),
#  ('i', "don't"),
#  ('i', 'think'),
#  ('i', 'think'),
#  ('i', "don't"),
#  ('i', 'guess'),
#  ('i', 'think'),
#  ('she', 'learned'),
#  ('we', 'can'),
#  ('i', "don't"),
#  ('we', "don't"),
#  ('we', "don't"),
#  ('she', 'do'),
#  ('she', 'plays'),
#  ('we', 'have_to'),
#  ('we', 'can'),
#  ('i', "don't"),
#  ('i', 'say'),
#  ('i', "don't"),
#  ('i', "wouldn't"),
#  ('i', 'eat'),
#  ('i', 'do'),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('she', 'said'),
#  ('she', 'wanted'),
#  ('i', 'ate'),
#  ('i', "don't"),
#  ('she', 'was'),
#  ('i', 'think'),
#  ('i', 'did'),
#  ('i', "don't"),
#  ('we', 'go'),
#  ('we', 'can'),
#  ('they', 'are'),
#  ('they', 'are'),
#  ('they', 'feel'),
#  ('i', "don't"),
#  ('i', 'thought'),
#  ('i', 'thought'),
#  ('i', "don't"),
#  ('we', "don't"),
#  ('we', 'plug'),
#  ('we', 'plug'),
#  ('we', 'put'),
#  ('we', "don't"),
#  ('we', 'put'),
#  ('we', 'put'),
#  ('we', 'put'),
#  ('we', 'put'),
#  ('we', 'put'),
#  ('we', 'put'),
#  ('we', 'put'),
#  ('i', "don't"),
#  ('i', 'want'),
#  ('i', 'thought'),
#  ('they', 'go'),
#  ('i', 'made'),
#  ('i', 'do'),
#  ('i', "don't"),
#  ('i', 'know'),
#  ('i', "don't"),
#  ('we', 'can'),
#  ('we', 'get'),
#  ('i', 'want'),
#  ('i', "don't"),
#  ('i', 'want'),
#  ('i', 'have'),
#  ('i', 'wonder'),
#  ('we', 'want'),
#  ('i', 'have'),
#  ('she', "doesn't"),
#  ('i', 'can'),
#  ('she', "doesn't"),
#  ('i', 'like'),
#  ('i', 'wonder'),
#  ('we', 'were'),
#  ('we', 'were'),
#  ('i', 'thought'),
#  ('we', 'were'),
#  ('we', 'thought'),
#  ('we', 'were'),
#  ('he', 'honey'),
#  ('i', 'should'),
#  ('i', 'should'),
#  ('they', 'are'),
#  ('we', 'making'),
#  ('he', 'looking'),
#  ('i', 'think'),
#  ('we', "don't"),
#  ('we', 'want'),
#  ('she', 'say'),
#  ('she', 'say'),
#  ('i', 'put'),
#  ('i', "can't"),
#  ('i', 'see'),
#  ('i', "don't"),
#  ('i', 'have_to'),
#  ('i', 'need'),
#  ('i', 'told'),
#  ('i', 'dreamed'),
#  ('we', 'were'),
#  ('i', 'honey'),
#  ('i', 'put'),
#  ('i', 'do'),
#  ('i', 'do'),
#  ('i', 'started'),
#  ('i', 'got'),
#  ('i', 'just'),
#  ('i', 'picked'),
#  ('he', 'was'),
#  ('he', 'read'),
#  ('he', 'said'),
#  ('i', 'think'),
#  ('i', 'hope'),
#  ('we', '<\\s>'),
#  ('we', 'know'),
#  ('we', '<\\s>'),
#  ('i', 'think'),
#  ('they', 'go'),
#  ('they', '<\\s>'),
#  ('they', 'go'),
#  ('i', "didn't"),
#  ('i', '<\\s>'),
#  ('i', 'took'),
#  ('i', '<\\s>'),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('we', 'can'),
#  ('i', 'think'),
#  ('we', 'should'),
#  ('i', 'just'),
#  ('we', 'are'),
#  ('i', 'put'),
#  ('he', 'like'),
#  ('he', 'had'),
#  ('he', 'what'),
#  ('he', 'or'),
#  ('he', 'hm'),
#  ('he', 'did'),
#  ('they', "don't"),
#  ('they', "don't"),
#  ('he', '<\\s>'),
#  ('he', '<\\s>'),
#  ('he', 'has'),
#  ('they', 'get'),
#  ('i', 'want'),
#  ('she', 'running'),
#  ('they', 'smell'),
#  ('they', 'are'),
#  ('she', 'said'),
#  ('i', 'know'),
#  ('i', "wasn't"),
#  ('i', 'was'),
#  ('i', 'said'),
#  ('i', 'was'),
#  ('i', '<\\s>'),
#  ('i', 'was'),
#  ('i', 'see'),
#  ('i', "can't"),
#  ('i', 'just'),
#  ('i', 'put'),
#  ('i', "shouldn't"),
#  ('i', 'was'),
#  ('i', 'see'),
#  ('he', '<\\s>'),
#  ('i', 'had'),
#  ('we', 'look'),
#  ('i', "don't"),
#  ('she', 'drew'),
#  ('i', 'want'),
#  ('i', 'see'),
#  ('they', 'drew'),
#  ('i', 'did'),
#  ('i', 'was'),
#  ('i', 'was'),
#  ('i', 'was'),
#  ('they', 'are'),
#  ('i', "didn't"),
#  ('i', 'am'),
#  ('i', 'think'),
#  ('i', 'help'),
#  ('he', 'goes'),
#  ('i', 'are'),
#  ('i', "don't"),
#  ('they', "don't"),
#  ('we', 'nomi'),
#  ('she', 'said'),
#  ('she', 'put'),
#  ('he', 'has'),
#  ('she', 'has'),
#  ('she', 'saw'),
#  ('i', "don't"),
#  ('i', 'think'),
#  ('i', "didn't"),
#  ('she', 'wants'),
#  ('we', 'used'),
#  ('we', 'called'),
#  ('we', 'played'),
#  ('we', 'call'),
#  ('we', 'had'),
#  ('we', "can't"),
#  ('we', "don't"),
#  ('we', "can't"),
#  ('i', 'told'),
#  ('she', 'does'),
#  ('she', 'will'),
#  ('she', 'is'),
#  ('i', 'think'),
#  ('she', 'just'),
#  ('she', 'wants'),
#  ('she', 'started'),
#  ('i', "don't"),
#  ('i', "didn't"),
#  ('we', 'still'),
#  ('i', "don't"),
#  ('they', 'may'),
#  ('i', 'think'),
#  ('i', 'mean'),
#  ('i', 'wanted'),
#  ('we', 'put'),
#  ('i', "can't"),
#  ('i', "didn't"),
#  ('i', 'hit'),
#  ('i', "don't"),
#  ('i', 'think'),
#  ('i', 'forgot'),
#  ('i', 'thought'),
#  ('we', 'came'),
#  ('we', 'wanted'),
#  ('we', 'wear'),
#  ('we', 'going'),
#  ('we', 'go'),
#  ('we', 'have_to'),
#  ('we', "can't"),
#  ('we', 'have_to'),
#  ('i', 'want'),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('she', 'did'),
#  ('we', 'eat'),
#  ('i', "can't"),
#  ('i', "didn't"),
#  ('i', "won't"),
#  ('i', 'thought'),
#  ('we', 'were'),
#  ('he', 'doing'),
#  ('i', "don't"),
#  ('we', 'have'),
#  ('i', 'think'),
#  ('we', 'have'),
#  ('i', 'think'),
#  ('i', 'had'),
#  ('i', 'see'),
#  ('i', "can't"),
#  ('i', 'explain'),
#  ('i', "can't"),
#  ('i', 'can'),
#  ('i', "can't"),
#  ('i', "don't"),
#  ('they', 'inside'),
#  ('i', 'see'),
#  ('i', 'thought'),
#  ('i', 'see'),
#  ('i', 'meant'),
#  ('i', 'said'),
#  ('i', 'came'),
#  ('she', 'really'),
#  ('she', 'wanted'),
#  ('we', 'just'),
#  ('we', 'just'),
#  ('she', 'wants'),
#  ('she', 'wants'),
#  ('i', "don't"),
#  ('i', 'know'),
#  ('i', 'have'),
#  ('she', 'treats'),
#  ('she', 'has'),
#  ('i', 'will'),
#  ('i', 'thought'),
#  ('i', 'will'),
#  ('we', 'put'),
#  ('i', "don't"),
#  ('we', 'said'),
#  ('we', 'going'),
#  ('i', 'going'),
#  ('i', 'have_to'),
#  ('i', 'will'),
#  ('i', 'will'),
#  ('i', 'have_to'),
#  ('we', 'should'),
#  ('we', 'going'),
#  ('i', "didn't"),
#  ('i', 'ask'),
#  ('he', 'was'),
#  ('i', "don't"),
#  ('they', 'look'),
#  ('they', 'do'),
#  ('we', 'get'),
#  ('they', 'break'),
#  ('i', "don't"),
#  ('she', 'have'),
#  ('she', 'has'),
#  ('she', 'goes'),
#  ('we', 'have'),
#  ('we', 'use'),
#  ('he', 'got'),
#  ('i', 'hear'),
#  ('i', 'want'),
#  ('we', 'have_to'),
#  ('i', "don't"),
#  ('i', 'gotta'),
#  ('i', 'forgot'),
#  ('i', "haven't"),
#  ('i', 'think'),
#  ('i', 'better'),
#  ('i', 'can'),
#  ('i', 'have_to'),
#  ('i', 'just'),
#  ('i', "don't"),
#  ('he', 'doing'),
#  ('he', 'doing'),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', "don't"),
#  ('i', 'guess'),
#  ('we', 'get'),
#  ('we', 'get'),
#  ('we', 'got'),
#  ('they', 'nice'),
#  ('we', 'got'),
#  ('i', 'know'),
#  ('i', 'think'),
#  ('i', 'was'),
#  ('i', 'was'),
#  ('i', 'was'),
#  ('i', 'can'),
#  ('i', 'tell'),
#  ('he', 'said'),
#  ('we', 'say'),
#  ('we', 'whoops'),
#  ('we', 'ask'),
#  ('we', 'ask'),
#  ('she', 'has_to'),
#  ('we', 'ask'),
#  ('i', 'have_to'),
#  ('i', "don't"),
#  ('i', 'want'),
#  ('i', 'want'),
#  ('i', 'want'),
#  ('i', 'know'),
#  ('i', 'know'),
#  ('i', 'know'),
#  ('i', 'want'),
#  ('i', 'give'),
#  ('i', 'give'),
#  ('i', "don't"),
#  ('she', 'has'),
#  ('she', 'can'),
#  ('she', "doesn't"),
#  ('she', "didn't"),
#  ('i', 'think'),
#  ('she', 'did'),
#  ('we', 'like'),
#  ('they', 'love'),
#  ('he', "didn't"),
#  ('i', 'have'),
#  ('he', 'hiding'),
#  ('they', "can't"),
#  ('they', '<\\s>'),
#  ('i', 'have_to'),
#  ('i', 'sometimes'),
#  ('i', '<\\s>'),
#  ('i', 'like'),
#  ('he', 'beed'),
#  ('he', 'looked'),
#  ('i', "won't"),
#  ('she', '<\\s>'),
#  ('she', 'make'),
#  ('she', "can't"),
#  ('she', '<\\s>'),
#  ('she', 'say'),
#  ('she', 'bit'),
#  ('she', 'does'),
#  ('she', 'is'),
#  ('i', 'think'),
#  ('i', 'took'),
#  ('i', 'think'),
#  ('i', "don't"),
#  ('i', 'see'),
#  ('we', 'have_to'),
#  ('i', "don't"),
#  ('we', 'can'),
#  ('we', 'can'),
#  ('we', 'got'),
#  ('i', 'am'),
#  ('i', 'never'),
#  ('i', 'wanna'),
#  ('i', 'know'),
#  ('i', 'wanna'),
#  ('i', "didn't"),
#  ('i', "didn't"),
#  ('she', 'does'),
#  ('we', 'want'),
#  ('i', 'think'),
#  ('we', 'need'),
#  ('i', 'want'),
#  ('i', 'want'),
#  ('we', 'have'),
#  ('we', 'have'),
#  ('i', 'want'),
#  ('i', 'want'),
#  ('i', 'got'),
#  ('i', "can't"),
#  ('we', 'should'),
#  ('we', "don't"),
#  ('i', 'thought'),
#  ('we', 'sometimes'),
#  ('i', 'think'),
#  ('we', 'put'),
#  ('i', 'want'),
#  ('we', 'can'),
#  ('we', 'can'),
#  ('i', 'put'),
#  ('we', 'go'),
#  ('we', 'will'),
#  ('i', "don't"),
#  ('we', 'make'),
#  ('i', "didn't"),
#  ('i', 'make'),
#  ('i', 'hope'),
#  ('i', "don't"),
#  ('i', 'bet'),
#  ('she', "didn't"),
#  ('she', 'said'),
#  ('we', 'went'),
#  ('we', 'might'),
#  ('we', 'were'),
#  ('he', 'say'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('we', 'can'),
#  ('i', 'have_to'),
#  ('i', 'try'),
#  ('i', 'like'),
#  ('i', 'start'),
#  ('i', 'can'),
#  ('i', 'think'),
#  ('we', 'went'),
#  ('i', 'thought'),
#  ('i', 'guess'),
#  ('i', 'guess'),
#  ('i', 'should'),
#  ('i', '<\\s>'),
#  ('i', 'know'),
#  ('i', 'saw'),
#  ('i', 'get'),
#  ('i', 'think'),
#  ('we', "don't"),
#  ('they', 'xxx'),
#  ('i', "don't"),
#  ('i', 'know'),
#  ('i', 'was'),
#  ('i', 'got'),
#  ('i', 'got'),
#  ('he', 'play'),
#  ('i', "didn't"),
#  ('i', 'think'),
#  ('she', 'has'),
#  ('i', 'think'),
#  ('i', 'think'),
#  ('she', 'getting'),
#  ('i', 'think'),
#  ('i', 'think'),
#  ('she', 'feels'),
#  ('she', '<\\s>'),
#  ('she', 'have'),
#  ('i', 'bet'),
#  ('she', 'feels'),
#  ('she', 'was'),
#  ('she', 'look'),
#  ('she', 'going'),
#  ('i', 'see'),
#  ('she', 'itching'),
#  ('she', 'must'),
#  ('she', 'looks'),
#  ('i', 'was')]

# %%
Naomi_mot_aXNX = [(pair[0], 'X') for pair in Naomi_mot_aX_Nom]
Naomi_mot_aXAX = [(pair[0], 'X') for pair in Naomi_mot_aX_Acc]
Naomi_mot_XbNX = [('X', pair[1]) for pair in Naomi_mot_Xb_Nom]
Naomi_mot_XbAX = [('X', pair[1]) for pair in Naomi_mot_Xb_Acc]

# %%
len(set(Naomi_mot_aXb_Nom))
# Out:
# 549

# %%
len(set(Naomi_mot_aXb_Acc))
# Out:
# 243

# %%
len(Naomi_mot_aX_Nom) + len(Naomi_mot_aX_Acc)
# Out:
# 1288

# %%
len(Naomi_mot_Xb_Nom) + len(Naomi_mot_Xb_Acc)
# Out:
# 1289

# %%
len(Naomi_mot_aX_Nom)
# Out:
# 926

# %%
len(set(Naomi_mot_aX_Nom))
# Out:
# 205

# %%
len(set(Naomi_mot_aX_Acc))
# Out:
# 143

# %%
print(len(Naomi_mot_Xb_Nom),len(set(Naomi_mot_Xb_Nom)))
# Out:
# 926 288

# %%
print(len(Naomi_mot_Xb_Acc),len(set(Naomi_mot_Xb_Acc)))
# Out:
# 363 146

# %%
sum([FreqDist(Naomi_mot_aXNX)[u] for u in (set(Naomi_mot_aXNX) - set(Naomi_mot_aXAX))])
# Out:
# 526

# %%
sum([FreqDist(Naomi_mot_aXAX)[u] for u in (set(Naomi_mot_aXAX) - set(Naomi_mot_aXNX))])
# Out:
# 344

# %%
len(set(Naomi_mot_aXNX) - set(Naomi_mot_aXAX))
# Out:
# 108

# %%
len(set(Naomi_mot_aXAX) - set(Naomi_mot_aXNX))
# Out:
# 90

# %%
len(set(Naomi_mot_XbNX) - set(Naomi_mot_XbAX))
# Out:
# 152

# %%
sum([FreqDist(Naomi_mot_XbNX)[u] for u in (set(Naomi_mot_XbNX) - set(Naomi_mot_XbAX))])
# Out:
# 771

# %%
len(set(Naomi_mot_XbAX) - set(Naomi_mot_XbNX))
# Out:
# 78

# %%
sum([FreqDist(Naomi_mot_XbAX)[u] for u in (set(Naomi_mot_XbAX) - set(Naomi_mot_XbNX))])
# Out:
# 208

# %% [markdown]
# ### Feedforward Neural Network

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Embedding, LSTM, Dense
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from keras.models import Sequential
import keras.utils as ku 
import numpy as np

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.preprocessing import text, sequence
from keras.preprocessing.text import Tokenizer
from keras import utils

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import LabelBinarizer, LabelEncoder
from sklearn.metrics import confusion_matrix

from sklearn.utils import shuffle
# Out:
# /Users/Ershui13/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from pandas import DataFrame

# %%
dfnn_aXb_Nom = DataFrame(Naomi_mot_aXb_Nom)
dfnn_aXb_Acc = DataFrame(Naomi_mot_aXb_Acc)
dfnn_aXb_Nom.columns = ['a', 'X', 'b']
dfnn_aXb_Acc.columns = ['a', 'X', 'b']
dfnn_aXb_Nom['case'] = 'NOM'
dfnn_aXb_Acc['case'] = 'ACC'
dfnn_aXb_Nom['predictor'] = dfnn_aXb_Nom[['a', 'b']].apply(lambda x: '_'.join(x), axis=1)
dfnn_aXb_Acc['predictor'] = dfnn_aXb_Acc[['a', 'b']].apply(lambda x: '_'.join(x), axis=1)

# %%
dfnn_Naomi_Nom = DataFrame(Naomi_aXb_Nom)
dfnn_Naomi_Acc = DataFrame(Naomi_aXb_Acc)
dfnn_Naomi_Nom.columns = ['a', 'X', 'b']
dfnn_Naomi_Acc.columns = ['a', 'X', 'b']
dfnn_Naomi_Nom['case'] = 'NOM'
dfnn_Naomi_Acc['case'] = 'ACC'
dfnn_Naomi_Nom['predictor'] = dfnn_Naomi_Nom[['a', 'b']].apply(lambda x: '_'.join(x), axis=1)
dfnn_Naomi_Acc['predictor'] = dfnn_Naomi_Acc[['a', 'b']].apply(lambda x: '_'.join(x), axis=1)

dfnn_Naomi = dfnn_Naomi_Nom.append(dfnn_Naomi_Acc)

dfnn_Naomi['aX'] = dfnn_Naomi['a'] + '_'
dfnn_Naomi['Xb'] =  '_' + dfnn_Naomi['b']

# %%
dfnn_Naomi
# Out:
#            a     X      b case     predictor        aX      Xb
# 0        dey  they   done  NOM      dey_done      dey_   _done
# 1        dey  they   done  NOM      dey_done      dey_   _done
# 2        dey  they   <\s>  NOM      dey_<\s>      dey_   _<\s>
# 3        <s>     i    yyy  NOM       <s>_yyy      <s>_    _yyy
# 4        <s>    he    dat  NOM       <s>_dat      <s>_    _dat
# 5        <s>    he      a  NOM         <s>_a      <s>_      _a
# 6        dey  they   <\s>  NOM      dey_<\s>      dey_   _<\s>
# 7        <s>     i    get  NOM       <s>_get      <s>_    _get
# 8        <s>     i    get  NOM       <s>_get      <s>_    _get
# 9        <s>     i    get  NOM       <s>_get      <s>_    _get
# 10       <s>     i  found  NOM     <s>_found      <s>_  _found
# 11       <s>     i    get  NOM       <s>_get      <s>_    _get
# 12       <s>     i    get  NOM       <s>_get      <s>_    _get
# 13       <s>     i    get  NOM       <s>_get      <s>_    _get
# 14       <s>     i    get  NOM       <s>_get      <s>_    _get
# 15       <s>     i   want  NOM      <s>_want      <s>_   _want
# 16       <s>     i    wan  NOM       <s>_wan      <s>_    _wan
# 17       <s>     i  can't  NOM     <s>_can't      <s>_  _can't
# 18       <s>     i    get  NOM       <s>_get      <s>_    _get
# 19       <s>     i    get  NOM       <s>_get      <s>_    _get
# 20       <s>     i    get  NOM       <s>_get      <s>_    _get
# 21       <s>     i    get  NOM       <s>_get      <s>_    _get
# 22       <s>     i    get  NOM       <s>_get      <s>_    _get
# 23       <s>     i    get  NOM       <s>_get      <s>_    _get
# 24       <s>     i    get  NOM       <s>_get      <s>_    _get
# 25       <s>     i    get  NOM       <s>_get      <s>_    _get
# 26       <s>     i    get  NOM       <s>_get      <s>_    _get
# 27       <s>     i    get  NOM       <s>_get      <s>_    _get
# 28       <s>     i    get  NOM       <s>_get      <s>_    _get
# 29       <s>     i    get  NOM       <s>_get      <s>_    _get
# ..       ...   ...    ...  ...           ...       ...     ...
# 446      <s>   her   name  ACC      <s>_name      <s>_   _name
# 447   inside   her    den  ACC    inside_den   inside_    _den
# 448     give    me      a  ACC        give_a     give_      _a
# 449     with   her  felts  ACC    with_felts     with_  _felts
# 450     gave   her      a  ACC        gave_a     gave_      _a
# 451     find    me   <\s>  ACC     find_<\s>     find_   _<\s>
# 452      eat   her   <\s>  ACC      eat_<\s>      eat_   _<\s>
# 453      eat    me   <\s>  ACC      eat_<\s>      eat_   _<\s>
# 454     find    me  daddy  ACC    find_daddy     find_  _daddy
# 455     help    me   very  ACC     help_very     help_   _very
# 456     give   her      a  ACC        give_a     give_      _a
# 457     feel   her  heart  ACC    feel_heart     feel_  _heart
# 458      put   her  shirt  ACC     put_shirt      put_  _shirt
# 459   here's   her  shirt  ACC  here's_shirt   here's_  _shirt
# 460     want  them     to  ACC       want_to     want_     _to
# 461      for   her    she  ACC       for_she      for_    _she
# 462      for   her    she  ACC       for_she      for_    _she
# 463  tickled   her     so  ACC    tickled_so  tickled_     _so
# 464    likes    me     to  ACC      likes_to    likes_     _to
# 465   tickle   her   <\s>  ACC   tickle_<\s>   tickle_   _<\s>
# 466       in   her    eye  ACC        in_eye       in_    _eye
# 467       in   her    eye  ACC        in_eye       in_    _eye
# 468       in   her    eye  ACC        in_eye       in_    _eye
# 469     take   her     to  ACC       take_to     take_     _to
# 470       to   her    own  ACC        to_own       to_    _own
# 471       at   her    own  ACC        at_own       at_    _own
# 472     with   her      a  ACC        with_a     with_      _a
# 473       to    us   <\s>  ACC       to_<\s>       to_   _<\s>
# 474     give   her   some  ACC     give_some     give_   _some
# 475      ate   her   food  ACC      ate_food      ate_   _food
#
# [2787 rows x 7 columns]

# %%
dfnn_aXb_Acc
# Out:
#            a     X         b case        predictor
# 0         to    me      <\s>  ACC          to_<\s>
# 1       take   him      <\s>  ACC        take_<\s>
# 2       take   him      <\s>  ACC        take_<\s>
# 3       give  them        to  ACC          give_to
# 4         to    me      <\s>  ACC          to_<\s>
# 5       give  them        to  ACC          give_to
# 6         to    me      <\s>  ACC          to_<\s>
# 7       show  them        to  ACC          show_to
# 8        got   her      feet  ACC         got_feet
# 9        got   her      feet  ACC         got_feet
# 10      give    me         a  ACC           give_a
# 11      want    me        to  ACC          want_to
# 12       let    me       get  ACC          let_get
# 13      show    me         a  ACC           show_a
# 14      show    me         a  ACC           show_a
# 15      what    me        to  ACC          what_to
# 16       use  them      very  ACC         use_very
# 17      with    me      <\s>  ACC        with_<\s>
# 18      tell    me     again  ACC       tell_again
# 19      with    me      <\s>  ACC        with_<\s>
# 20       let    me       see  ACC          let_see
# 21       has   her   glasses  ACC      has_glasses
# 22       let    me       get  ACC          let_get
# 23       see   her      <\s>  ACC         see_<\s>
# 24       let    me    attach  ACC       let_attach
# 25        on  them      <\s>  ACC          on_<\s>
# 26        of  them        to  ACC            of_to
# 27      tell    us      when  ACC        tell_when
# 28        of   him      <\s>  ACC          of_<\s>
# 29      pull  them        up  ACC          pull_up
# ..       ...   ...       ...  ...              ...
# 333    after    me      <\s>  ACC       after_<\s>
# 334      get  them  recorded  ACC     get_recorded
# 335     with  them      <\s>  ACC        with_<\s>
# 336     tell  them      what  ACC        tell_what
# 337      hit   him        if  ACC           hit_if
# 338   behind   him      <\s>  ACC      behind_<\s>
# 339      let    me       see  ACC          let_see
# 340  next_to    me     honey  ACC    next_to_honey
# 341     knew   her      from  ACC        knew_from
# 342     with  them      <\s>  ACC        with_<\s>
# 343     want    me        to  ACC          want_to
# 344     open  them        or  ACC          open_or
# 345     take  them       out  ACC         take_out
# 346   finish   her  sentence  ACC  finish_sentence
# 347      for   him      <\s>  ACC         for_<\s>
# 348    shake  them      <\s>  ACC       shake_<\s>
# 349      let    me       put  ACC          let_put
# 350      put  them        on  ACC           put_on
# 351      let    me       xxx  ACC          let_xxx
# 352       in   her       eye  ACC           in_eye
# 353       in   her       eye  ACC           in_eye
# 354  checked   her      ears  ACC     checked_ears
# 355    about   her      ears  ACC       about_ears
# 356      <s>   her     fever  ACC        <s>_fever
# 357     with   her      <\s>  ACC        with_<\s>
# 358      for   her       too  ACC          for_too
# 359     want    me        to  ACC          want_to
# 360      for   her      <\s>  ACC         for_<\s>
# 361      for   her       too  ACC          for_too
# 362     make   her     voice  ACC       make_voice
#
# [363 rows x 5 columns]

# %%
dfnn_aXb = dfnn_aXb_Nom.append(dfnn_aXb_Acc)
# Out:
#            a     X         b case        predictor
# 0         no     i     don't  NOM         no_don't
# 1        <s>     i     don't  NOM        <s>_don't
# 2        <s>     i     think  NOM        <s>_think
# 3         do  they     smell  NOM         do_smell
# 4         do  they     smell  NOM         do_smell
# 5        <s>    we       saw  NOM          <s>_saw
# 6        <s>     i       put  NOM          <s>_put
# 7        are  they    eating  NOM       are_eating
# 8       look    he        is  NOM          look_is
# 9        <s>    he        is  NOM           <s>_is
# 10      good     i       can  NOM         good_can
# 11       <s>     i       can  NOM          <s>_can
# 12       now     i     think  NOM        now_think
# 13      good   she       got  NOM         good_got
# 14       but     i   decided  NOM      but_decided
# 15     maybe   she     would  NOM      maybe_would
# 16       and    we      will  NOM         and_will
# 17       are  they      <\s>  NOM         are_<\s>
# 18       <s>  they       are  NOM          <s>_are
# 19       <s>     i      want  NOM         <s>_want
# 20       now     i      want  NOM         now_want
# 21      nomi     i      want  NOM        nomi_want
# 22       <s>     i      want  NOM         <s>_want
# 23       <s>     i     think  NOM        <s>_think
# 24        so   she     won't  NOM         so_won't
# 25     there   she      goes  NOM       there_goes
# 26      does   she      <\s>  NOM        does_<\s>
# 27        am     i     right  NOM         am_right
# 28    what's   she     doing  NOM     what's_doing
# 29       <s>     i      just  NOM         <s>_just
# ..       ...   ...       ...  ...              ...
# 333    after    me      <\s>  ACC       after_<\s>
# 334      get  them  recorded  ACC     get_recorded
# 335     with  them      <\s>  ACC        with_<\s>
# 336     tell  them      what  ACC        tell_what
# 337      hit   him        if  ACC           hit_if
# 338   behind   him      <\s>  ACC      behind_<\s>
# 339      let    me       see  ACC          let_see
# 340  next_to    me     honey  ACC    next_to_honey
# 341     knew   her      from  ACC        knew_from
# 342     with  them      <\s>  ACC        with_<\s>
# 343     want    me        to  ACC          want_to
# 344     open  them        or  ACC          open_or
# 345     take  them       out  ACC         take_out
# 346   finish   her  sentence  ACC  finish_sentence
# 347      for   him      <\s>  ACC         for_<\s>
# 348    shake  them      <\s>  ACC       shake_<\s>
# 349      let    me       put  ACC          let_put
# 350      put  them        on  ACC           put_on
# 351      let    me       xxx  ACC          let_xxx
# 352       in   her       eye  ACC           in_eye
# 353       in   her       eye  ACC           in_eye
# 354  checked   her      ears  ACC     checked_ears
# 355    about   her      ears  ACC       about_ears
# 356      <s>   her     fever  ACC        <s>_fever
# 357     with   her      <\s>  ACC        with_<\s>
# 358      for   her       too  ACC          for_too
# 359     want    me        to  ACC          want_to
# 360      for   her      <\s>  ACC         for_<\s>
# 361      for   her       too  ACC          for_too
# 362     make   her     voice  ACC       make_voice
#
# [1289 rows x 5 columns]

# %%
dfnn_aXb
# Out:
#               a     X          b case        predictor           aX  \
# 723         are    we      going  NOM        are_going         are_
# 496        look     i       made  NOM        look_made        look_
# 115        tell    me     what's  ACC      tell_what's        tell_
# 354     checked   her       ears  ACC     checked_ears     checked_
# 550         did    he       read  NOM         did_read         did_
# 342        with  them       <\s>  ACC        with_<\s>        with_
# 100        that    we      could  NOM       that_could        that_
# 173       stuck  them         in  ACC         stuck_in       stuck_
# 302         <s>    he      broke  NOM        <s>_broke         <s>_
# 245          is   she      doing  NOM         is_doing          is_
# 122     dropped  them       even  ACC     dropped_even     dropped_
# 244         for    me        for  ACC          for_for         for_
# 210       visit    me       <\s>  ACC       visit_<\s>       visit_
# 217       teach   her          a  ACC          teach_a       teach_
# 24          let    me     attach  ACC       let_attach         let_
# 460         <s>     i         do  NOM           <s>_do         <s>_
# 759      what's    he      doing  NOM     what's_doing      what's_
# 754       think     i     better  NOM     think_better       think_
# 5          give  them         to  ACC          give_to        give_
# 272         <s>    he        had  NOM          <s>_had         <s>_
# 856         how    we  sometimes  NOM    how_sometimes         how_
# 489          do    we        put  NOM           do_put          do_
# 872          no   she     didn't  NOM        no_didn't          no_
# 259       isn't   she       <\s>  NOM       isn't_<\s>       isn't_
# 113        tell    me       more  ACC        tell_more        tell_
# 832          so    we        can  NOM           so_can          so_
# 186         let    me        fix  ACC          let_fix         let_
# 364         are  they      doing  NOM        are_doing         are_
# 896        well     i      think  NOM       well_think        well_
# 78         want    me         to  ACC          want_to        want_
# ..          ...   ...        ...  ...              ...          ...
# 237         for  them       <\s>  ACC         for_<\s>         for_
# 85          <s>  they      won't  NOM        <s>_won't         <s>_
# 232         for    us         to  ACC           for_to         for_
# 141         are  they     eating  NOM       are_eating         are_
# 527         <s>     i      think  NOM        <s>_think         <s>_
# 629         <s>   she        has  NOM          <s>_has         <s>_
# 726        well     i       will  NOM        well_will        well_
# 744    charcoal    we        use  NOM     charcoal_use    charcoal_
# 358         for   her        too  ACC          for_too         for_
# 9           <s>    he         is  NOM           <s>_is         <s>_
# 322         ask   her       what  ACC         ask_what         ask_
# 906          uh     i      think  NOM         uh_think          uh_
# 805         can     i       have  NOM         can_have         can_
# 498         <s>     i      don't  NOM        <s>_don't         <s>_
# 397         are  they    cooking  NOM      are_cooking         are_
# 791        know     i       know  NOM        know_know        know_
# 240         <s>     i      don't  NOM        <s>_don't         <s>_
# 377          do    we       know  NOM          do_know          do_
# 213         <s>     i    thought  NOM      <s>_thought         <s>_
# 826        toys     i      think  NOM       toys_think        toys_
# 133         <s>     i      don't  NOM        <s>_don't         <s>_
# 159         put   her       over  ACC         put_over         put_
# 638         did    we       call  NOM         did_call         did_
# 738         and  they      break  NOM        and_break         and_
# 611         <s>  they       drew  NOM         <s>_drew         <s>_
# 294  understand  them       <\s>  ACC  understand_<\s>  understand_
# 686         <s>     i      don't  NOM        <s>_don't         <s>_
# 524         <s>  they        are  NOM          <s>_are         <s>_
# 551         <s>    he       said  NOM         <s>_said         <s>_
# 154         are  they      doing  NOM        are_doing         are_
#
#              Xb
# 723      _going
# 496       _made
# 115     _what's
# 354       _ears
# 550       _read
# 342       _<\s>
# 100      _could
# 173         _in
# 302      _broke
# 245      _doing
# 122       _even
# 244        _for
# 210       _<\s>
# 217          _a
# 24      _attach
# 460         _do
# 759      _doing
# 754     _better
# 5           _to
# 272        _had
# 856  _sometimes
# 489        _put
# 872     _didn't
# 259       _<\s>
# 113       _more
# 832        _can
# 186        _fix
# 364      _doing
# 896      _think
# 78          _to
# ..          ...
# 237       _<\s>
# 85       _won't
# 232         _to
# 141     _eating
# 527      _think
# 629        _has
# 726       _will
# 744        _use
# 358        _too
# 9           _is
# 322       _what
# 906      _think
# 805       _have
# 498      _don't
# 397    _cooking
# 791       _know
# 240      _don't
# 377       _know
# 213    _thought
# 826      _think
# 133      _don't
# 159       _over
# 638       _call
# 738      _break
# 611       _drew
# 294       _<\s>
# 686      _don't
# 524        _are
# 551       _said
# 154      _doing
#
# [1289 rows x 7 columns]

# %%
dfnn_aXb['aX'] = dfnn_aXb['a']+'_'
# Out:
# /Users/Ershui13/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfnn_aXb['Xb'] = '_' + dfnn_aXb['b']
# Out:
# /Users/Ershui13/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfnn_aXb = shuffle(dfnn_aXb)

# %%
dfnn_Naomi = shuffle(dfnn_Naomi)

# %%
train_size = int(len(dfnn_aXb) * 0.8) 
print ("Train size: %d" % train_size)
print ("Test size: %d" % (len(dfnn_aXb) - train_size))
# Out:
# Train size: 1031
# Test size: 258

# %% [markdown]
# ### train on aX

# %%
train_word = dfnn_aXb['aX'][:train_size]
train_case = dfnn_aXb['case'][:train_size]
test_word = dfnn_aXb['aX'][train_size:]
test_case = dfnn_aXb['case'][train_size:]

num_cases = 2
vocab_size = 15000
batch_size = 100

tokenizer = Tokenizer(num_words=1000, char_level=False)
tokenizer.fit_on_texts(train_word)
x_train = tokenizer.texts_to_matrix(train_word)
x_test = tokenizer.texts_to_matrix(test_word)

encoder = LabelEncoder()
encoder.fit(train_case)
y_train = encoder.transform(train_case)
y_test = encoder.transform(test_case)

epochs = 3
num_classes = np.max(y_train) + 1
y_train = utils.to_categorical(y_train, num_classes)
y_test = utils.to_categorical(y_test, num_classes)

number_hidden_units = 100 

model = Sequential()
model.add(Dense(number_hidden_units, input_shape=(1000,)))
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))   # this is the output layer
model.add(Activation('sigmoid'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1)
# Out:
# Train on 927 samples, validate on 104 samples
# Epoch 1/3
# 927/927 [==============================] - 2s 2ms/step - loss: 0.6432 - acc: 0.6904 - val_loss: 0.5910 - val_acc: 0.7115
# Epoch 2/3
# 927/927 [==============================] - 0s 319us/step - loss: 0.5350 - acc: 0.7184 - val_loss: 0.4882 - val_acc: 0.7115
# Epoch 3/3
# 927/927 [==============================] - 0s 384us/step - loss: 0.4380 - acc: 0.7249 - val_loss: 0.4069 - val_acc: 0.7500

# %%
score = model.evaluate(x_test, y_test, verbose=1)
print('aX-Test accuracy:', score[1])
# Out:
# 258/258 [==============================] - 0s 82us/step
# aX-Test accuracy: 0.7635658914728682

# %% [markdown]
# #### test on Naomi

# %%
train_word = dfnn_aXb['aX']
train_case = dfnn_aXb['case']
test_word = dfnn_Naomi['aX']
test_case = dfnn_Naomi['case']

num_cases = 2
vocab_size = 15000
batch_size = 100

tokenizer = Tokenizer(num_words=1000, char_level=False)
tokenizer.fit_on_texts(train_word)
x_train = tokenizer.texts_to_matrix(train_word)
x_test = tokenizer.texts_to_matrix(test_word)

encoder = LabelEncoder()
encoder.fit(train_case)
y_train = encoder.transform(train_case)
y_test = encoder.transform(test_case)

epochs = 3
num_classes = np.max(y_train) + 1
y_train = utils.to_categorical(y_train, num_classes)
y_test = utils.to_categorical(y_test, num_classes)

number_hidden_units = 100 

model = Sequential()
model.add(Dense(number_hidden_units, input_shape=(1000,)))
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))   # this is the output layer
model.add(Activation('sigmoid'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1)
# Out:
# Train on 1160 samples, validate on 129 samples
# Epoch 1/3
# 1160/1160 [==============================] - 2s 2ms/step - loss: 0.6317 - acc: 0.6974 - val_loss: 0.5471 - val_acc: 0.7519
# Epoch 2/3
# 1160/1160 [==============================] - 0s 393us/step - loss: 0.4947 - acc: 0.7198 - val_loss: 0.4120 - val_acc: 0.7519
# Epoch 3/3
# 1160/1160 [==============================] - 0s 323us/step - loss: 0.3803 - acc: 0.8233 - val_loss: 0.3121 - val_acc: 0.9225

# %%
score = model.evaluate(x_test, y_test, verbose=1)
print('Naomi aX-Test accuracy:', score[1])
# Out:
# 2787/2787 [==============================] - 0s 70us/step
# Naomi aX-Test accuracy: 0.8776462145676355

# %% [markdown]
# ### train on Xb

# %%
train_word = dfnn_aXb['Xb'][:train_size]
train_case = dfnn_aXb['case'][:train_size]
test_word = dfnn_aXb['Xb'][train_size:]
test_case = dfnn_aXb['case'][train_size:]

num_cases = 2
vocab_size = 15000
batch_size = 100

tokenizer = Tokenizer(num_words=1000, char_level=False)
tokenizer.fit_on_texts(train_word)
x_train = tokenizer.texts_to_matrix(train_word)
x_test = tokenizer.texts_to_matrix(test_word)

encoder = LabelEncoder()
encoder.fit(train_case)
y_train = encoder.transform(train_case)
y_test = encoder.transform(test_case)

epochs = 3
num_classes = np.max(y_train) + 1
y_train = utils.to_categorical(y_train, num_classes)
y_test = utils.to_categorical(y_test, num_classes)

number_hidden_units = 100 

model = Sequential()
model.add(Dense(number_hidden_units, input_shape=(1000,)))
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))   # this is the output layer
model.add(Activation('sigmoid'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1)
# Out:
# Train on 927 samples, validate on 104 samples
# Epoch 1/3
# 927/927 [==============================] - 2s 2ms/step - loss: 0.6571 - acc: 0.6807 - val_loss: 0.6102 - val_acc: 0.7115
# Epoch 2/3
# 927/927 [==============================] - 0s 351us/step - loss: 0.5710 - acc: 0.7174 - val_loss: 0.5161 - val_acc: 0.7115
# Epoch 3/3
# 927/927 [==============================] - 0s 338us/step - loss: 0.4882 - acc: 0.7174 - val_loss: 0.4420 - val_acc: 0.7115

# %%
score = model.evaluate(x_test, y_test, verbose=1)
print('Xb-Test accuracy:', score[1])
# Out:
# 258/258 [==============================] - 0s 91us/step
# Xb-Test accuracy: 0.7248062015503876

# %% [markdown]
# #### test on Naomi

# %%
train_word = dfnn_aXb['Xb']
train_case = dfnn_aXb['case']
test_word = dfnn_Naomi['Xb']
test_case = dfnn_Naomi['case']

num_cases = 2
vocab_size = 15000
batch_size = 100

tokenizer = Tokenizer(num_words=1000, char_level=False)
tokenizer.fit_on_texts(train_word)
x_train = tokenizer.texts_to_matrix(train_word)
x_test = tokenizer.texts_to_matrix(test_word)

encoder = LabelEncoder()
encoder.fit(train_case)
y_train = encoder.transform(train_case)
y_test = encoder.transform(test_case)

epochs = 3
num_classes = np.max(y_train) + 1
y_train = utils.to_categorical(y_train, num_classes)
y_test = utils.to_categorical(y_test, num_classes)

number_hidden_units = 100 

model = Sequential()
model.add(Dense(number_hidden_units, input_shape=(1000,)))
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))   # this is the output layer
model.add(Activation('sigmoid'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1)
# Out:
# Train on 1160 samples, validate on 129 samples
# Epoch 1/3
# 1160/1160 [==============================] - 2s 2ms/step - loss: 0.6505 - acc: 0.6724 - val_loss: 0.5913 - val_acc: 0.7519
# Epoch 2/3
# 1160/1160 [==============================] - 0s 324us/step - loss: 0.5447 - acc: 0.7147 - val_loss: 0.4808 - val_acc: 0.7519
# Epoch 3/3
# 1160/1160 [==============================] - 0s 317us/step - loss: 0.4453 - acc: 0.7388 - val_loss: 0.4162 - val_acc: 0.8062

# %%
score = model.evaluate(x_test, y_test, verbose=1)
print('Naomi Xb-Test accuracy:', score[1])
# Out:
# 2787/2787 [==============================] - 0s 71us/step
# Naomi Xb-Test accuracy: 0.8955866523143164

# %% [markdown]
# ### train on aXb

# %%
train_word = dfnn_aXb['predictor'][:train_size]
train_case = dfnn_aXb['case'][:train_size]
test_word = dfnn_aXb['predictor'][train_size:]
test_case = dfnn_aXb['case'][train_size:]

num_cases = 2
vocab_size = 15000
batch_size = 100

tokenizer = Tokenizer(num_words=1000, char_level=False)
tokenizer.fit_on_texts(train_word)
x_train = tokenizer.texts_to_matrix(train_word)
x_test = tokenizer.texts_to_matrix(test_word)

encoder = LabelEncoder()
encoder.fit(train_case)
y_train = encoder.transform(train_case)
y_test = encoder.transform(test_case)

epochs = 3
num_classes = np.max(y_train) + 1
y_train = utils.to_categorical(y_train, num_classes)
y_test = utils.to_categorical(y_test, num_classes)

number_hidden_units = 100 

model = Sequential()
model.add(Dense(number_hidden_units, input_shape=(1000,)))
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))   # this is the output layer
model.add(Activation('sigmoid'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1)
# Out:
# Train on 927 samples, validate on 104 samples
# Epoch 1/3
# 927/927 [==============================] - 2s 2ms/step - loss: 0.6424 - acc: 0.6893 - val_loss: 0.5819 - val_acc: 0.7212
# Epoch 2/3
# 927/927 [==============================] - 0s 308us/step - loss: 0.5232 - acc: 0.7292 - val_loss: 0.4739 - val_acc: 0.7212
# Epoch 3/3
# 927/927 [==============================] - 0s 309us/step - loss: 0.4220 - acc: 0.7616 - val_loss: 0.3953 - val_acc: 0.7981

# %%
score = model.evaluate(x_test, y_test, verbose=1)
print('aXb-Test accuracy:', score[1])
# Out:
# 258/258 [==============================] - 0s 97us/step
# aXb-Test accuracy: 0.8023255813953488

# %%
train_word = dfnn_aXb['predictor']
train_case = dfnn_aXb['case']
test_word = dfnn_Naomi['predictor']
test_case = dfnn_Naomi['case']

num_cases = 2
vocab_size = 15000
batch_size = 100

tokenizer = Tokenizer(num_words=1000, char_level=False)
tokenizer.fit_on_texts(train_word)
x_train = tokenizer.texts_to_matrix(train_word)
x_test = tokenizer.texts_to_matrix(test_word)

encoder = LabelEncoder()
encoder.fit(train_case)
y_train = encoder.transform(train_case)
y_test = encoder.transform(test_case)

epochs = 3
num_classes = np.max(y_train) + 1
y_train = utils.to_categorical(y_train, num_classes)
y_test = utils.to_categorical(y_test, num_classes)

number_hidden_units = 100 

model = Sequential()
model.add(Dense(number_hidden_units, input_shape=(1000,)))
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))   # this is the output layer
model.add(Activation('sigmoid'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1)
# Out:
# Train on 1160 samples, validate on 129 samples
# Epoch 1/3
# 1160/1160 [==============================] - 2s 2ms/step - loss: 0.6253 - acc: 0.6879 - val_loss: 0.5382 - val_acc: 0.7597
# Epoch 2/3
# 1160/1160 [==============================] - 0s 335us/step - loss: 0.4831 - acc: 0.7371 - val_loss: 0.4273 - val_acc: 0.7907
# Epoch 3/3
# 1160/1160 [==============================] - 0s 365us/step - loss: 0.3793 - acc: 0.8224 - val_loss: 0.3488 - val_acc: 0.8682

# %%
score = model.evaluate(x_test, y_test, verbose=1)
print('Naomi aXb-Test accuracy:', score[1])
# Out:
# 2787/2787 [==============================] - 0s 67us/step
# Naomi aXb-Test accuracy: 0.8643702906457849

# %% [markdown]
# ### Desicion Tree

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics 
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble

import pandas, numpy, string
from keras.preprocessing import text, sequence
from keras import layers, models, optimizers

# %% [markdown]
# ### test on aX

# %%
texts = dfnn_aXb['aX']
labels = dfnn_aXb['case']
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(texts, labels)

# %%
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_y)
valid_y = encoder.fit_transform(valid_y)

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', max_features=5000)
tfidf_vect.fit(texts)
xtrain_tfidf =  tfidf_vect.transform(train_x)
xvalid_tfidf =  tfidf_vect.transform(valid_x)

# %%
def train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net=False):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)
    
    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_valid)
    
    if is_neural_net:
        predictions = predictions.argmax(axis=-1)
    
    return metrics.accuracy_score(predictions, valid_y)

# %%
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("aX, NB, WordLevel TF-IDF: ", accuracy)
# Out:
# aX, NB, WordLevel TF-IDF:  0.891640866873065

# %%
accuracy = train_model(linear_model.LogisticRegression(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("aX, LR, WordLevel TF-IDF: ", accuracy)
# Out:
# aX, LR, WordLevel TF-IDF:  0.8421052631578947

# %%
accuracy = train_model(ensemble.RandomForestClassifier(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("aX, RF, WordLevel TF-IDF: ", accuracy)
# Out:
# aX, RF, WordLevel TF-IDF:  0.8823529411764706

# %% [markdown]
# #### test on Naomi

# %%
texts = dfnn_aXb['aX']
labels = dfnn_aXb['case']
train_x = texts
valid_x = dfnn_Naomi['aX']
train_y = labels
valid_y = dfnn_Naomi['case']

# %%
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_y)
valid_y = encoder.fit_transform(valid_y)

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', max_features=5000)
tfidf_vect.fit(texts)
xtrain_tfidf =  tfidf_vect.transform(train_x)
xvalid_tfidf =  tfidf_vect.transform(valid_x)

# %%
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("Naomi, aX, NB, WordLevel TF-IDF: ", accuracy)
# Out:
# Naomi, aX, NB, WordLevel TF-IDF:  0.9221385001794044

# %%
accuracy = train_model(ensemble.RandomForestClassifier(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("Naomi, aX, RF, WordLevel TF-IDF: ", accuracy)
# Out:
# Naomi, aX, RF, WordLevel TF-IDF:  0.9207032651596699

# %% [markdown]
# ### test on Xb

# %%
texts = dfnn_aXb['Xb']
labels = dfnn_aXb['case']
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(texts, labels)

# %%
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_y)
valid_y = encoder.fit_transform(valid_y)

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', max_features=5000)
tfidf_vect.fit(texts)
xtrain_tfidf =  tfidf_vect.transform(train_x)
xvalid_tfidf =  tfidf_vect.transform(valid_x)

# %%
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("Xb, NB, WordLevel TF-IDF: ", accuracy)
# Out:
# Xb, NB, WordLevel TF-IDF:  0.8761609907120743

# %%
accuracy = train_model(ensemble.RandomForestClassifier(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("Xb, RF, WordLevel TF-IDF: ", accuracy)
# Out:
# Xb, RF, WordLevel TF-IDF:  0.8730650154798761

# %% [markdown]
# ##### test on Naomi

# %%
texts = dfnn_aXb['Xb']
labels = dfnn_aXb['case']
train_x = texts
valid_x = dfnn_Naomi['Xb']
train_y = labels
valid_y = dfnn_Naomi['case']

# %%
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_y)
valid_y = encoder.fit_transform(valid_y)

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', max_features=5000)
tfidf_vect.fit(texts)
xtrain_tfidf =  tfidf_vect.transform(train_x)
xvalid_tfidf =  tfidf_vect.transform(valid_x)

# %%
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("Naomi, Xb, NB, WordLevel TF-IDF: ", accuracy)
# Out:
# Naomi, Xb, NB, WordLevel TF-IDF:  0.9138858988159311

# %%
accuracy = train_model(ensemble.RandomForestClassifier(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("Naomi, Xb, RF, WordLevel TF-IDF: ", accuracy)
# Out:
# Naomi, Xb, RF, WordLevel TF-IDF:  0.9131682813060639

# %% [markdown]
# ### test on aXb

# %%
texts = dfnn_aXb['predictor']
labels = dfnn_aXb['case']
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(texts, labels)

# %%
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_y)
valid_y = encoder.fit_transform(valid_y)

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', max_features=5000)
tfidf_vect.fit(texts)
xtrain_tfidf =  tfidf_vect.transform(train_x)
xvalid_tfidf =  tfidf_vect.transform(valid_x)

# %%
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("aXb, NB, WordLevel TF-IDF: ", accuracy)
# Out:
# aXb, NB, WordLevel TF-IDF:  0.8761609907120743

# %%
accuracy = train_model(ensemble.RandomForestClassifier(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("aXb, RF, WordLevel TF-IDF: ", accuracy)
# Out:
# aXb, RF, WordLevel TF-IDF:  0.8792569659442725

# %% [markdown]
# #### Test on Naomi

# %%
texts = dfnn_aXb['predictor']
labels = dfnn_aXb['case']
train_x = texts
valid_x = dfnn_Naomi['predictor']
train_y = labels
valid_y = dfnn_Naomi['case']

# %%
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_y)
valid_y = encoder.fit_transform(valid_y)

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', max_features=5000)
tfidf_vect.fit(texts)
xtrain_tfidf =  tfidf_vect.transform(train_x)
xvalid_tfidf =  tfidf_vect.transform(valid_x)

# %%
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("aXb, NB, WordLevel TF-IDF: ", accuracy)
# Out:
# aXb, NB, WordLevel TF-IDF:  0.8747757445281665

# %%
accuracy = train_model(ensemble.RandomForestClassifier(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("aXb, RF, WordLevel TF-IDF: ", accuracy)
# Out:
# aXb, RF, WordLevel TF-IDF:  0.8858988159311088
